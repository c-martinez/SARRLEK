# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 500)

# %%
from SPARQLWrapper import SPARQLWrapper, CSV
from io import StringIO

# %%
sparql = SPARQLWrapper("http://localhost:8890/sparql")

# %% [markdown]
# Two SPARQL optimizations:
#  - Internal query generates a list of RIDs which we are interested on:
#  ```SPARQL
#  SELECT ?rid WHERE {
#     <http://www.radlex.org/RID/#RID1302> radlex:Has_Part{1,2} ?rid
#  }
#  ```
#  The `radlex:Has_Part{1,2}` syntax allows us to fetch children and grand children of the ID of interest. In this case, the sub-parts and sub-sub-parts of RID1302 (right lung). See [sparql documentation](https://www.w3.org/TR/sparql11-property-paths/) for more details.
#  - Then external query finds the `preferred_name` and `synonym` of the IDs of interest.

# %%
qry = """
PREFIX radlex: <http://www.radlex.org/RID/#>

SELECT ?rid ?name ?synonym 
WHERE {
  {
    SELECT ?rid WHERE {
      <http://www.radlex.org/RID/#RID1302> radlex:Has_Part{1,2} ?rid
    }
  } .
  # ?rid radlex:Preferred_name ?name .
  OPTIONAL{?rid radlex:Synonym ?synonym  }
}
"""

# %%
sparql.setQuery(qry)
sparql.setReturnFormat(CSV)
res = sparql.queryAndConvert()
resAsStr = res.decode('utf-8')

# %%
df = pd.read_csv(StringIO(resAsStr))
df = df.fillna('')
df.head(200)
# Out:
#                                    rid  \
# 0   http://www.radlex.org/RID/#RID1303
# 1   http://www.radlex.org/RID/#RID1303
# 2   http://www.radlex.org/RID/#RID1304
# 3   http://www.radlex.org/RID/#RID1306
# 4   http://www.radlex.org/RID/#RID1308
# 5   http://www.radlex.org/RID/#RID1315
# 6   http://www.radlex.org/RID/#RID1315
# 7   http://www.radlex.org/RID/#RID1318
# 8   http://www.radlex.org/RID/#RID1310
# 9   http://www.radlex.org/RID/#RID1310
# 10  http://www.radlex.org/RID/#RID1310
# 11  http://www.radlex.org/RID/#RID1311
# 12  http://www.radlex.org/RID/#RID1313
# 13  http://www.radlex.org/RID/#RID1316
# 14  http://www.radlex.org/RID/#RID1320
# 15  http://www.radlex.org/RID/#RID1322
# 16  http://www.radlex.org/RID/#RID1324
# 17  http://www.radlex.org/RID/#RID1349
# 18  http://www.radlex.org/RID/#RID1350
# 19  http://www.radlex.org/RID/#RID1353
# 20  http://www.radlex.org/RID/#RID1356
# 21  http://www.radlex.org/RID/#RID1358
#
#                                                    name  \
# 0   upper lobe of right lung
# 1   upper lobe of right lung
# 2   apical segment of upper lobe of right lung
# 3   posterior segment of upper lobe of right lung
# 4   anterior segment of upper lobe of right lung
# 5   lower lobe of right lung
# 6   lower lobe of right lung
# 7   medial basal segment of lower lobe of right lung
# 8   middle lobe of lung
# 9   middle lobe of lung
# 10  middle lobe of lung
# 11  lateral segment of middle lobe of right lung
# 12  medial segment of middle lobe of right lung
# 13  superior segment of lower lobe of right lung
# 14  anterior basal segment of lower lobe of right lung
# 15  lateral basal segment of lower lobe of right lung
# 16  posterior basal segment of lower lobe of right lung
# 17  left upper lung zone
# 18  right upper lung zone
# 19  right mid lung zone
# 20  right lower lung zone
# 21  axillary region of right lung
#
#                                     synonym
# 0   RUL
# 1   right upper lobe
# 2   S1 segment of upper lobe of right lung
# 3   S2 segment of upper lobe of right lung
# 4   S3 segment of upper lobe of right lung
# 5   RLL
# 6   right lower lobe
# 7   S7 segment of lower lobe of right lung
# 8   RML
# 9   middle lobe of right lung
# 10  right middle lobe
# 11  S4 segment of middle lobe of right lung
# 12  S5 segment of middle lobe of right lung
# 13  S6 segment of lower lobe of right lung
# 14  S8 segment of lower lobe of right lung
# 15  S9 segment of lower lobe of right lung
# 16  S10 segment of lower lobe of right lung
# 17
# 18
# 19
# 20
# 21

# %%
Lst = list(set(df['name'].tolist() + df['synonym'].tolist()))
Lst = [ x for x in Lst if x!='' ]

# %%
terms = pd.DataFrame(Lst, columns=['meanings'])
terms['keys'] = 'RIGHT_LUNG'
terms
# Out:
#                                                meanings        keys
# 0   anterior basal segment of lower lobe of right lung   RIGHT_LUNG
# 1   lower lobe of right lung                             RIGHT_LUNG
# 2   right middle lobe                                    RIGHT_LUNG
# 3   lateral segment of middle lobe of right lung         RIGHT_LUNG
# 4   right mid lung zone                                  RIGHT_LUNG
# 5   S9 segment of lower lobe of right lung               RIGHT_LUNG
# 6   S10 segment of lower lobe of right lung              RIGHT_LUNG
# 7   anterior segment of upper lobe of right lung         RIGHT_LUNG
# 8   medial basal segment of lower lobe of right lung     RIGHT_LUNG
# 9   S4 segment of middle lobe of right lung              RIGHT_LUNG
# 10  left upper lung zone                                 RIGHT_LUNG
# 11  RML                                                  RIGHT_LUNG
# 12  S8 segment of lower lobe of right lung               RIGHT_LUNG
# 13  S7 segment of lower lobe of right lung               RIGHT_LUNG
# 14  RUL                                                  RIGHT_LUNG
# 15  middle lobe of right lung                            RIGHT_LUNG
# 16  upper lobe of right lung                             RIGHT_LUNG
# 17  medial segment of middle lobe of right lung          RIGHT_LUNG
# 18  right upper lobe                                     RIGHT_LUNG
# 19  right upper lung zone                                RIGHT_LUNG
# 20  S5 segment of middle lobe of right lung              RIGHT_LUNG
# 21  S3 segment of upper lobe of right lung               RIGHT_LUNG
# 22  S2 segment of upper lobe of right lung               RIGHT_LUNG
# 23  apical segment of upper lobe of right lung           RIGHT_LUNG
# 24  RLL                                                  RIGHT_LUNG
# 25  posterior segment of upper lobe of right lung        RIGHT_LUNG
# 26  superior segment of lower lobe of right lung         RIGHT_LUNG
# 27  posterior basal segment of lower lobe of right lung  RIGHT_LUNG
# 28  right lower lobe                                     RIGHT_LUNG
# 29  axillary region of right lung                        RIGHT_LUNG
# 30  right lower lung zone                                RIGHT_LUNG
# 31  S1 segment of upper lobe of right lung               RIGHT_LUNG
# 32  S6 segment of lower lobe of right lung               RIGHT_LUNG
# 33  middle lobe of lung                                  RIGHT_LUNG
# 34  lateral basal segment of lower lobe of right lung    RIGHT_LUNG
