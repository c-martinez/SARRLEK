# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 500)

# %%
from SPARQLWrapper import SPARQLWrapper, CSV
from io import StringIO

# %%
sparql = SPARQLWrapper("http://localhost:8890/sparql")

# %%
qry = """
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX radlex: <http://www.radlex.org/RID/#>

SELECT DISTINCT ?RID ?name ?sub_name1 ?sub_name2 ?sub_name3 ?sub_name4 ?sub_name5 ?sub_name6 ?sub_name7 ?sub_name8 ?sub_name9 ?sub_name10 ?sub_name11 ?sub_name12
WHERE
{
 # ?term radlex:Preferred_name ?name .
 # ?term rdfs:label ?RID .
 FILTER regex(?RID,"RID39128",'i')
 OPTIONAL{?term radlex:Has_Subtype ?Sub_type1  .
 # ?Sub_type1 radlex:Preferred_name ?sub_name1 .
 OPTIONAL{?Sub_type1 radlex:Has_Subtype ?Sub_type2  .
 # ?Sub_type2 radlex:Preferred_name ?sub_name2 .
 OPTIONAL{?Sub_type2 radlex:Has_Subtype ?Sub_type3  .
 # ?Sub_type3 radlex:Preferred_name ?sub_name3 .

 
}}}}
 """

# %%
sparql.setQuery(qry)
sparql.setReturnFormat(CSV)
res = sparql.queryAndConvert()
resAsStr = res.decode('utf-8')

# %%
df = pd.read_csv(StringIO(resAsStr))
df.head(200)
# Out:
#          RID     name                  sub_name1             sub_name2  \
# 0   RID39128  process  anesthesia                 general anesthesia
# 1   RID39128  process  anesthesia                 local anesthesia
# 2   RID39128  process  anesthesia                 tumescent anesthesia
# 3   RID39128  process  anesthesia                 regional anesthesia
# 4   RID39128  process  anesthesia                 epidural anesthesia
# 5   RID39128  process  anesthesia                 spinal anesthesia
# 6   RID39128  process  biological process         swallowing
# 7   RID39128  process  biological process         metabolism
# 8   RID39128  process  biological process         gestation
# 9   RID39128  process  biological process         peristalsis
# 10  RID39128  process  biological process         wall motion
# 11  RID39128  process  biological process         periosteal reaction
# 12  RID39128  process  biological process         voiding
# 13  RID39128  process  biological process         motor function
# 14  RID39128  process  ventilation                NaN
# 15  RID39128  process  treatment planning         NaN
# 16  RID39128  process  uptake                     NaN
# 17  RID39128  process  imaging protocol           NaN
# 18  RID39128  process  redistribution             NaN
# 19  RID39128  process  change                     NaN
# 20  RID39128  process  suppression                NaN
# 21  RID39128  process  monitored anesthesia care  NaN
# 22  RID39128  process  training                   NaN
# 23  RID39128  process  motion                     NaN
# 24  RID39128  process  stimulation                NaN
#
#     sub_name3  sub_name4  sub_name5  sub_name6  sub_name7  sub_name8  \
# 0  NaN        NaN        NaN        NaN        NaN        NaN
# 1  NaN        NaN        NaN        NaN        NaN        NaN
# 2  NaN        NaN        NaN        NaN        NaN        NaN
# 3  NaN        NaN        NaN        NaN        NaN        NaN
# 4  NaN        NaN        NaN        NaN        NaN        NaN
# 5  NaN        NaN        NaN        NaN        NaN        NaN
# 6  NaN        NaN        NaN        NaN        NaN        NaN
# 7  NaN        NaN        NaN        NaN        NaN        NaN
# 8  NaN        NaN        NaN        NaN        NaN        NaN
# 9  NaN        NaN        NaN        NaN        NaN        NaN
# 10 NaN        NaN        NaN        NaN        NaN        NaN
# 11 NaN        NaN        NaN        NaN        NaN        NaN
# 12 NaN        NaN        NaN        NaN        NaN        NaN
# 13 NaN        NaN        NaN        NaN        NaN        NaN
# 14 NaN        NaN        NaN        NaN        NaN        NaN
# 15 NaN        NaN        NaN        NaN        NaN        NaN
# 16 NaN        NaN        NaN        NaN        NaN        NaN
# 17 NaN        NaN        NaN        NaN        NaN        NaN
# 18 NaN        NaN        NaN        NaN        NaN        NaN
# 19 NaN        NaN        NaN        NaN        NaN        NaN
# 20 NaN        NaN        NaN        NaN        NaN        NaN
# 21 NaN        NaN        NaN        NaN        NaN        NaN
# 22 NaN        NaN        NaN        NaN        NaN        NaN
# 23 NaN        NaN        NaN        NaN        NaN        NaN
# 24 NaN        NaN        NaN        NaN        NaN        NaN
#
#     sub_name9  sub_name10  sub_name11  sub_name12
# 0  NaN        NaN         NaN         NaN
# 1  NaN        NaN         NaN         NaN
# 2  NaN        NaN         NaN         NaN
# 3  NaN        NaN         NaN         NaN
# 4  NaN        NaN         NaN         NaN
# 5  NaN        NaN         NaN         NaN
# 6  NaN        NaN         NaN         NaN
# 7  NaN        NaN         NaN         NaN
# 8  NaN        NaN         NaN         NaN
# 9  NaN        NaN         NaN         NaN
# 10 NaN        NaN         NaN         NaN
# 11 NaN        NaN         NaN         NaN
# 12 NaN        NaN         NaN         NaN
# 13 NaN        NaN         NaN         NaN
# 14 NaN        NaN         NaN         NaN
# 15 NaN        NaN         NaN         NaN
# 16 NaN        NaN         NaN         NaN
# 17 NaN        NaN         NaN         NaN
# 18 NaN        NaN         NaN         NaN
# 19 NaN        NaN         NaN         NaN
# 20 NaN        NaN         NaN         NaN
# 21 NaN        NaN         NaN         NaN
# 22 NaN        NaN         NaN         NaN
# 23 NaN        NaN         NaN         NaN
# 24 NaN        NaN         NaN         NaN

# %%
Lst = [df['name'].tolist(), df['sub_name1'].tolist(), df['sub_name2'].tolist()]

# %%
print(Lst)
# Out:
# [['process', 'process', 'process', 'process', 'process', 'process', 'process', 'process', 'process', 'process', 'process', 'process', 'process', 'process', 'process', 'process', 'process', 'process', 'process', 'process', 'process', 'process', 'process', 'process', 'process'], ['anesthesia', 'anesthesia', 'anesthesia', 'anesthesia', 'anesthesia', 'anesthesia', 'biological process', 'biological process', 'biological process', 'biological process', 'biological process', 'biological process', 'biological process', 'biological process', 'ventilation', 'treatment planning', 'uptake', 'imaging protocol', 'redistribution', 'change', 'suppression', 'monitored anesthesia care', 'training', 'motion', 'stimulation'], ['general anesthesia', 'local anesthesia', 'tumescent anesthesia', 'regional anesthesia', 'epidural anesthesia', 'spinal anesthesia', 'swallowing', 'metabolism', 'gestation', 'peristalsis', 'wall motion', 'periosteal reaction', 'voiding', 'motor function', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]]

# %%
values = []
for lists in Lst:
    for string in lists:
        if str(string) == 'nan':
            pass
        else:
            values.append(string)

values = list(set(values))
dict_Radlex = {}
dict_Radlex['Process_related_words'] = values
print(dict_Radlex['Process_related_words'])
# Out:
# ['imaging protocol', 'stimulation', 'regional anesthesia', 'monitored anesthesia care', 'motion', 'motor function', 'wall motion', 'ventilation', 'swallowing', 'metabolism', 'change', 'local anesthesia', 'training', 'treatment planning', 'peristalsis', 'uptake', 'biological process', 'voiding', 'spinal anesthesia', 'periosteal reaction', 'process', 'epidural anesthesia', 'gestation', 'general anesthesia', 'anesthesia', 'suppression', 'tumescent anesthesia', 'redistribution']
