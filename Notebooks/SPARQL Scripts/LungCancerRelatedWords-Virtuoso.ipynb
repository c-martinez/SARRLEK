# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 500)

# %%
from SPARQLWrapper import SPARQLWrapper, CSV
from io import StringIO

# %%
sparql = SPARQLWrapper("http://localhost:8890/sparql")

# %%
qry = """
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX radlex: <http://www.radlex.org/RID/#>

SELECT DISTINCT ?RID ?name ?sub_name1 ?sub_name2 ?sub_name3 ?synonym1 ?synonym2 ?synonym3
WHERE
{
 # ?term radlex:Preferred_name ?name .
 FILTER regex(?name,"lung cancer",'i')
 # ?term rdfs:label ?RID .
 OPTIONAL{?term radlex:Synonym ?synonym  .}
 
 OPTIONAL{?term radlex:Is_A ?Sub_type1  .
 # ?Sub_type1 radlex:Preferred_name ?sub_name1 .
 # ?Sub_type1 rdfs:label ?sub1_RID .
 
 OPTIONAL{?Sub_type1 radlex:Synonym ?synonym1  .}
 
 OPTIONAL{?Sub_type1 radlex:Has_Subtype ?Sub_type2  .
 # ?Sub_type2 radlex:Preferred_name ?sub_name2 .
 # ?Sub_type2 rdfs:label ?sub2_RID .
 
 OPTIONAL{?Sub_type2 radlex:Synonym ?synonym2  .}
 
 OPTIONAL{?Sub_type2 radlex:Has_Subtype ?Sub_type3  .
 # ?Sub_type3 radlex:Preferred_name ?sub_name3 .
 # ?Sub_type3 rdfs:label ?sub3_RID .
 
 OPTIONAL{?Sub_type3 radlex:Synonym ?synonym3  .}
 

 }}}}
 """

# %%
sparql.setQuery(qry)
sparql.setReturnFormat(CSV)
res = sparql.queryAndConvert()
resAsStr = res.decode('utf-8')

# %%
df = pd.read_csv(StringIO(resAsStr))
df.head(200)
# Out:
#          RID         name                     sub_name1  \
# 0   RID45686  lung cancer  malignant neoplastic disease
# 1   RID45686  lung cancer  malignant neoplastic disease
# 2   RID45686  lung cancer  malignant neoplastic disease
# 3   RID45686  lung cancer  malignant neoplastic disease
# 4   RID45686  lung cancer  malignant neoplastic disease
# 5   RID45686  lung cancer  malignant neoplastic disease
# 6   RID45686  lung cancer  malignant neoplastic disease
# 7   RID45686  lung cancer  malignant neoplastic disease
# 8   RID45686  lung cancer  malignant neoplastic disease
# 9   RID45686  lung cancer  malignant neoplastic disease
# 10  RID45686  lung cancer  malignant neoplastic disease
# 11  RID45686  lung cancer  malignant neoplastic disease
# 12  RID45686  lung cancer  malignant neoplastic disease
# 13  RID45686  lung cancer  malignant neoplastic disease
# 14  RID45686  lung cancer  malignant neoplastic disease
# 15  RID45686  lung cancer  malignant neoplastic disease
# 16  RID45686  lung cancer  malignant neoplastic disease
# 17  RID45686  lung cancer  malignant neoplastic disease
# 18  RID45686  lung cancer  malignant neoplastic disease
# 19  RID45686  lung cancer  malignant neoplastic disease
# 20  RID45686  lung cancer  malignant neoplastic disease
# 21  RID45686  lung cancer  malignant neoplastic disease
# 22  RID45686  lung cancer  malignant neoplastic disease
#
#                        sub_name2                                   sub_name3  \
# 0   prostate cancer               clinically significant prostate cancer
# 1   lymphoma                      T-cell lymphoma
# 2   prostate cancer               clinically significant prostate cancer
# 3   prostate cancer               clinically significant prostate cancer
# 4   lymphoma                      non-Hodgkin lymphoma
# 5   lymphoma                      Hodgkin lymphoma
# 6   malignant neoplasm of pelvis  malignant neoplasm of genitourinary system
# 7   lymphoma                      large cell lymphoma
# 8   metastatic disease            NaN
# 9   gastric cancer                NaN
# 10  ovarian cancer                NaN
# 11  breast cancer                 NaN
# 12  melanoma                      NaN
# 13  pancreatic cancer             NaN
# 14  head and neck cancer          NaN
# 15  endometrial cancer            NaN
# 16  cervical cancer               NaN
# 17  lung cancer                   NaN
# 18  cancer of unknown primary     NaN
# 19  esophageal cancer             NaN
# 20  testicular cancer             NaN
# 21  colorectal cancer             NaN
# 22  thyroid cancer                NaN
#
#    synonym1                   synonym2                                synonym3
# 0   cancer   carcinoma of prostate      intermediate high risk prostate cancer
# 1   cancer   lymphosarcoma              malignant histiocytosis syndrome
# 2   cancer   cancer of prostate         intermediate high risk prostate cancer
# 3   cancer   prostate cancer, NOS       intermediate high risk prostate cancer
# 4   cancer   lymphosarcoma              NaN
# 5   cancer   lymphosarcoma              NaN
# 6   cancer   malignant tumor of pelvis  NaN
# 7   cancer   lymphosarcoma              NaN
# 8   cancer   metastasis                 NaN
# 9   cancer   stomach cancer             NaN
# 10  cancer   NaN                        NaN
# 11  cancer   NaN                        NaN
# 12  cancer   NaN                        NaN
# 13  cancer   NaN                        NaN
# 14  cancer   NaN                        NaN
# 15  cancer   NaN                        NaN
# 16  cancer   NaN                        NaN
# 17  cancer   NaN                        NaN
# 18  cancer   NaN                        NaN
# 19  cancer   NaN                        NaN
# 20  cancer   NaN                        NaN
# 21  cancer   NaN                        NaN
# 22  cancer   NaN                        NaN

# %%
Lst = [df['name'].tolist(), df['sub_name1'].tolist(), df['sub_name2'].tolist(), df['sub_name3'].tolist(), df['synonym1'].tolist(), df['synonym2'].tolist(), df['synonym3'].tolist()]

# %%
print(Lst)
# Out:
# [['lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer'], ['malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease'], ['prostate cancer', 'lymphoma', 'prostate cancer', 'prostate cancer', 'lymphoma', 'lymphoma', 'malignant neoplasm of pelvis', 'lymphoma', 'metastatic disease', 'gastric cancer', 'ovarian cancer', 'breast cancer', 'melanoma', 'pancreatic cancer', 'head and neck cancer', 'endometrial cancer', 'cervical cancer', 'lung cancer', 'cancer of unknown primary', 'esophageal cancer', 'testicular cancer', 'colorectal cancer', 'thyroid cancer'], ['clinically significant prostate cancer', 'T-cell lymphoma', 'clinically significant prostate cancer', 'clinically significant prostate cancer', 'non-Hodgkin lymphoma', 'Hodgkin lymphoma', 'malignant neoplasm of genitourinary system', 'large cell lymphoma', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan], ['cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer'], ['carcinoma of prostate', 'lymphosarcoma', 'cancer of prostate', 'prostate cancer, NOS', 'lymphosarcoma', 'lymphosarcoma', 'malignant tumor of pelvis', 'lymphosarcoma', 'metastasis', 'stomach cancer', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan], ['intermediate high risk prostate cancer', 'malignant histiocytosis syndrome', 'intermediate high risk prostate cancer', 'intermediate high risk prostate cancer', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]]

# %%
Cancer_values = []
for lists in Lst:
    for string in lists:
        if str(string) == 'nan':
            pass
        else:
            Cancer_values.append(string)

Cancer_values = list(set(Cancer_values))
print(Cancer_values)
# Out:
# ['cancer of prostate', 'malignant tumor of pelvis', 'ovarian cancer', 'breast cancer', 'stomach cancer', 'cancer of unknown primary', 'malignant histiocytosis syndrome', 'testicular cancer', 'lymphoma', 'gastric cancer', 'T-cell lymphoma', 'clinically significant prostate cancer', 'carcinoma of prostate', 'cancer', 'metastasis', 'lung cancer', 'cervical cancer', 'malignant neoplasm of pelvis', 'head and neck cancer', 'melanoma', 'non-Hodgkin lymphoma', 'pancreatic cancer', 'metastatic disease', 'malignant neoplastic disease', 'prostate cancer', 'Hodgkin lymphoma', 'esophageal cancer', 'lymphosarcoma', 'endometrial cancer', 'prostate cancer, NOS', 'malignant neoplasm of genitourinary system', 'large cell lymphoma', 'colorectal cancer', 'thyroid cancer', 'intermediate high risk prostate cancer']
