# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 500)

# %%
from SPARQLWrapper import SPARQLWrapper, CSV
from io import StringIO

# %%
sparql = SPARQLWrapper("http://localhost:8890/sparql")

# %%
qry = """
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX radlex: <http://www.radlex.org/RID/#>

SELECT DISTINCT ?RID ?name ?sub_name1 ?sub_name2 ?sub_name3 ?sub_name4 ?sub_name5 ?sub_name6 ?sub_name7 ?sub_name8 ?sub_name9 ?sub_name10 ?sub_name11 ?sub_name12
WHERE
{
 # ?term radlex:Preferred_name ?name .
 # ?term rdfs:label ?RID .
 FILTER regex(?RID,"RID3874",'i')
 OPTIONAL{?term radlex:Has_Subtype ?Sub_type1  .
 # ?Sub_type1 radlex:Preferred_name ?sub_name1 .
 OPTIONAL{?Sub_type1 radlex:Has_Subtype ?Sub_type2  .
 # ?Sub_type2 radlex:Preferred_name ?sub_name2 .
 OPTIONAL{?Sub_type2 radlex:Has_Subtype ?Sub_type3  .
 # ?Sub_type3 radlex:Preferred_name ?sub_name3 .

 
}}}}
 """

# %%
sparql.setQuery(qry)
sparql.setReturnFormat(CSV)
res = sparql.queryAndConvert()
resAsStr = res.decode('utf-8')

# %%
df = pd.read_csv(StringIO(resAsStr))
df.head(200)
# Out:
#          RID                                                    name  \
# 0   RID38740  non-ionic iso-osmolar dimeric iodinated contrast agent
# 1   RID38740  non-ionic iso-osmolar dimeric iodinated contrast agent
# 2   RID38741  iodixanol
# 3   RID38741  iodixanol
# 4   RID3874   mass
# 5   RID38740  non-ionic iso-osmolar dimeric iodinated contrast agent
# 6   RID3874   mass
# 7   RID3874   mass
# 8   RID38747  phase descriptor
# 9   RID3874   mass
# 10  RID3874   mass
# 11  RID3874   mass
# 12  RID3874   mass
# 13  RID3874   mass
# 14  RID3874   mass
# 15  RID3874   mass
# 16  RID38747  phase descriptor
# 17  RID38747  phase descriptor
# 18  RID38745  iotrolan
# 19  RID3874   mass
# 20  RID3874   mass
# 21  RID38749  single phase
# 22  RID38743  Visipaque-270
# 23  RID38744  Visipaque-320
# 24  RID38742  Visipaque
# 25  RID38742  Visipaque
# 26  RID38748  multiphase
# 27  RID38746  Isovist
#
#                               sub_name1      sub_name2      sub_name3  \
# 0   iodixanol                            Visipaque      Visipaque-270
# 1   iodixanol                            Visipaque      Visipaque-320
# 2   Visipaque                            Visipaque-270  NaN
# 3   Visipaque                            Visipaque-320  NaN
# 4   chest mass                           lung mass      NaN
# 5   iotrolan                             Isovist        NaN
# 6   irregular mass                       NaN            NaN
# 7   oval mass                            NaN            NaN
# 8   single phase                         NaN            NaN
# 9   subthreshold lesion                  NaN            NaN
# 10  round mass                           NaN            NaN
# 11  lobular mass                         NaN            NaN
# 12  mass in or on skin                   NaN            NaN
# 13  breast mass                          NaN            NaN
# 14  benign prostatic hyperplasia nodule  NaN            NaN
# 15  bone density                         NaN            NaN
# 16  triphase                             NaN            NaN
# 17  multiphase                           NaN            NaN
# 18  Isovist                              NaN            NaN
# 19  liver mass                           NaN            NaN
# 20  focal dominant mass                  NaN            NaN
# 21  NaN                                  NaN            NaN
# 22  NaN                                  NaN            NaN
# 23  NaN                                  NaN            NaN
# 24  Visipaque-270                        NaN            NaN
# 25  Visipaque-320                        NaN            NaN
# 26  NaN                                  NaN            NaN
# 27  NaN                                  NaN            NaN
#
#     sub_name4  sub_name5  sub_name6  sub_name7  sub_name8  sub_name9  \
# 0  NaN        NaN        NaN        NaN        NaN        NaN
# 1  NaN        NaN        NaN        NaN        NaN        NaN
# 2  NaN        NaN        NaN        NaN        NaN        NaN
# 3  NaN        NaN        NaN        NaN        NaN        NaN
# 4  NaN        NaN        NaN        NaN        NaN        NaN
# 5  NaN        NaN        NaN        NaN        NaN        NaN
# 6  NaN        NaN        NaN        NaN        NaN        NaN
# 7  NaN        NaN        NaN        NaN        NaN        NaN
# 8  NaN        NaN        NaN        NaN        NaN        NaN
# 9  NaN        NaN        NaN        NaN        NaN        NaN
# 10 NaN        NaN        NaN        NaN        NaN        NaN
# 11 NaN        NaN        NaN        NaN        NaN        NaN
# 12 NaN        NaN        NaN        NaN        NaN        NaN
# 13 NaN        NaN        NaN        NaN        NaN        NaN
# 14 NaN        NaN        NaN        NaN        NaN        NaN
# 15 NaN        NaN        NaN        NaN        NaN        NaN
# 16 NaN        NaN        NaN        NaN        NaN        NaN
# 17 NaN        NaN        NaN        NaN        NaN        NaN
# 18 NaN        NaN        NaN        NaN        NaN        NaN
# 19 NaN        NaN        NaN        NaN        NaN        NaN
# 20 NaN        NaN        NaN        NaN        NaN        NaN
# 21 NaN        NaN        NaN        NaN        NaN        NaN
# 22 NaN        NaN        NaN        NaN        NaN        NaN
# 23 NaN        NaN        NaN        NaN        NaN        NaN
# 24 NaN        NaN        NaN        NaN        NaN        NaN
# 25 NaN        NaN        NaN        NaN        NaN        NaN
# 26 NaN        NaN        NaN        NaN        NaN        NaN
# 27 NaN        NaN        NaN        NaN        NaN        NaN
#
#     sub_name10  sub_name11  sub_name12
# 0  NaN         NaN         NaN
# 1  NaN         NaN         NaN
# 2  NaN         NaN         NaN
# 3  NaN         NaN         NaN
# 4  NaN         NaN         NaN
# 5  NaN         NaN         NaN
# 6  NaN         NaN         NaN
# 7  NaN         NaN         NaN
# 8  NaN         NaN         NaN
# 9  NaN         NaN         NaN
# 10 NaN         NaN         NaN
# 11 NaN         NaN         NaN
# 12 NaN         NaN         NaN
# 13 NaN         NaN         NaN
# 14 NaN         NaN         NaN
# 15 NaN         NaN         NaN
# 16 NaN         NaN         NaN
# 17 NaN         NaN         NaN
# 18 NaN         NaN         NaN
# 19 NaN         NaN         NaN
# 20 NaN         NaN         NaN
# 21 NaN         NaN         NaN
# 22 NaN         NaN         NaN
# 23 NaN         NaN         NaN
# 24 NaN         NaN         NaN
# 25 NaN         NaN         NaN
# 26 NaN         NaN         NaN
# 27 NaN         NaN         NaN

# %%
Lst = [df['name'].tolist(), df['sub_name1'].tolist(), df['sub_name2'].tolist(), df['sub_name3'].tolist()]

# %%
print(Lst)
# Out:
# [['non-ionic iso-osmolar dimeric iodinated contrast agent', 'non-ionic iso-osmolar dimeric iodinated contrast agent', 'iodixanol', 'iodixanol', 'mass', 'non-ionic iso-osmolar dimeric iodinated contrast agent', 'mass', 'mass', 'phase descriptor', 'mass', 'mass', 'mass', 'mass', 'mass', 'mass', 'mass', 'phase descriptor', 'phase descriptor', 'iotrolan', 'mass', 'mass', 'single phase', 'Visipaque-270', 'Visipaque-320', 'Visipaque', 'Visipaque', 'multiphase', 'Isovist'], ['iodixanol', 'iodixanol', 'Visipaque', 'Visipaque', 'chest mass', 'iotrolan', 'irregular mass', 'oval mass', 'single phase', 'subthreshold lesion', 'round mass', 'lobular mass', 'mass in or on skin', 'breast mass', 'benign prostatic hyperplasia nodule', 'bone density', 'triphase', 'multiphase', 'Isovist', 'liver mass', 'focal dominant mass', nan, nan, nan, 'Visipaque-270', 'Visipaque-320', nan, nan], ['Visipaque', 'Visipaque', 'Visipaque-270', 'Visipaque-320', 'lung mass', 'Isovist', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan], ['Visipaque-270', 'Visipaque-320', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]]

# %%
values = []
for lists in Lst:
    for string in lists:
        if str(string) == 'nan':
            pass
        else:
            values.append(string)

values = list(set(values))
dict_Radlex = {}
dict_Radlex['Process_related_words'] = values
print(dict_Radlex['Process_related_words'])
# Out:
# ['lung mass', 'iodixanol', 'subthreshold lesion', 'chest mass', 'benign prostatic hyperplasia nodule', 'mass in or on skin', 'Visipaque-270', 'single phase', 'oval mass', 'irregular mass', 'multiphase', 'Visipaque', 'bone density', 'lobular mass', 'phase descriptor', 'triphase', 'mass', 'focal dominant mass', 'breast mass', 'liver mass', 'non-ionic iso-osmolar dimeric iodinated contrast agent', 'Visipaque-320', 'iotrolan', 'Isovist', 'round mass']
