# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 500)

# %%
from SPARQLWrapper import SPARQLWrapper, CSV
from io import StringIO

# %%
sparql = SPARQLWrapper("http://localhost:8890/sparql")

# %%
qry = """
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX radlex: <http://www.radlex.org/RID/#>

SELECT DISTINCT ?RID ?name ?sub_name1 ?synonym ?synonym1
WHERE
{
 # ?term radlex:Preferred_name ?name .
 FILTER regex(?name,"cancer",'i')
 # ?term rdfs:label ?RID .
 OPTIONAL{?term radlex:Synonym ?synonym  .}
 
 OPTIONAL{?term radlex:Has_Subtype ?Sub_type1  .
 # ?Sub_type1 radlex:Preferred_name ?sub_name1 .
 # ?Sub_type1 rdfs:label ?sub1_RID .
 
 OPTIONAL{?Sub_type1 radlex:Synonym ?synonym1  .}
 
 OPTIONAL{?Sub_type1 radlex:Has_Subtype ?Sub_type2  .
 # ?Sub_type2 radlex:Preferred_name ?sub_name2 .
 # ?Sub_type2 rdfs:label ?sub2_RID .
 
 OPTIONAL{?Sub_type2 radlex:Synonym ?synonym2  .}
 
 OPTIONAL{?Sub_type2 radlex:Has_Subtype ?Sub_type3  .
 # ?Sub_type3 radlex:Preferred_name ?sub_name3 .
 # ?Sub_type3 rdfs:label ?sub3_RID .
 
 OPTIONAL{?Sub_type3 radlex:Synonym ?synonym3  .}
 

 }}}}
 """

# %%
sparql.setQuery(qry)
sparql.setReturnFormat(CSV)
res = sparql.queryAndConvert()
resAsStr = res.decode('utf-8')

# %%
df = pd.read_csv(StringIO(resAsStr))
df.head(200)
# Out:
#          RID                                    name  \
# 0   RID45683  cervical cancer
# 1   RID45688  pancreatic cancer
# 2   RID45696  esophageal cancer
# 3   RID34623  gastric cancer
# 4   RID45689  prostate cancer
# 5   RID45689  prostate cancer
# 6   RID45689  prostate cancer
# 7   RID45682  breast cancer
# 8   RID45684  colorectal cancer
# 9   RID45685  endometrial cancer
# 10  RID45686  lung cancer
# 11  RID45687  ovarian cancer
# 12  RID45691  thyroid cancer
# 13  RID45697  head and neck cancer
# 14  RID45744  cancer of unknown primary
# 15  RID45690  testicular cancer
# 16  RID49502  clinically significant prostate cancer
# 17  RID49705  inflammatory cancer skin invasion
#
#                                  sub_name1  \
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   clinically significant prostate cancer
# 5   clinically significant prostate cancer
# 6   clinically significant prostate cancer
# 7   NaN
# 8   NaN
# 9   NaN
# 10  NaN
# 11  NaN
# 12  NaN
# 13  NaN
# 14  NaN
# 15  NaN
# 16  NaN
# 17  NaN
#
#                                    synonym  \
# 0   NaN
# 1   NaN
# 2   NaN
# 3   stomach cancer
# 4   cancer of prostate
# 5   carcinoma of prostate
# 6   prostate cancer, NOS
# 7   NaN
# 8   NaN
# 9   NaN
# 10  NaN
# 11  NaN
# 12  NaN
# 13  NaN
# 14  NaN
# 15  NaN
# 16  intermediate high risk prostate cancer
# 17  NaN
#
#                                   synonym1
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   intermediate high risk prostate cancer
# 5   intermediate high risk prostate cancer
# 6   intermediate high risk prostate cancer
# 7   NaN
# 8   NaN
# 9   NaN
# 10  NaN
# 11  NaN
# 12  NaN
# 13  NaN
# 14  NaN
# 15  NaN
# 16  NaN
# 17  NaN

# %%
Lst = [df['name'].tolist(), df['sub_name1'].tolist(), df['synonym'].tolist(), df['synonym1'].tolist()]

# %%
print(Lst)
# Out:
# [['cervical cancer', 'pancreatic cancer', 'esophageal cancer', 'gastric cancer', 'prostate cancer', 'prostate cancer', 'prostate cancer', 'breast cancer', 'colorectal cancer', 'endometrial cancer', 'lung cancer', 'ovarian cancer', 'thyroid cancer', 'head and neck cancer', 'cancer of unknown primary', 'testicular cancer', 'clinically significant prostate cancer', 'inflammatory cancer skin invasion'], [nan, nan, nan, nan, 'clinically significant prostate cancer', 'clinically significant prostate cancer', 'clinically significant prostate cancer', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan], [nan, nan, nan, 'stomach cancer', 'cancer of prostate', 'carcinoma of prostate', 'prostate cancer, NOS', nan, nan, nan, nan, nan, nan, nan, nan, nan, 'intermediate high risk prostate cancer', nan], [nan, nan, nan, nan, 'intermediate high risk prostate cancer', 'intermediate high risk prostate cancer', 'intermediate high risk prostate cancer', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]]

# %%
Cancer_values = []
for lists in Lst:
    for string in lists:
        if str(string) == 'nan':
            pass
        else:
            Cancer_values.append(string)

Cancer_values = list(set(Cancer_values))
print(Cancer_values)
# Out:
# ['cervical cancer', 'breast cancer', 'head and neck cancer', 'pancreatic cancer', 'intermediate high risk prostate cancer', 'esophageal cancer', 'cancer of unknown primary', 'lung cancer', 'cancer of prostate', 'endometrial cancer', 'colorectal cancer', 'thyroid cancer', 'clinically significant prostate cancer', 'inflammatory cancer skin invasion', 'carcinoma of prostate', 'prostate cancer, NOS', 'stomach cancer', 'prostate cancer', 'testicular cancer', 'gastric cancer', 'ovarian cancer']
