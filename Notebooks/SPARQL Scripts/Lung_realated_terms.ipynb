# %%
from rdflib import Graph, ConjunctiveGraph
import pandas as pd
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 500)

g = ConjunctiveGraph()

# %%
g.parse("Radlex&Clever/owlapi.xrdf")
# Out:
# <Graph identifier=file:///C:/Users/320026487/Downloads/NLP_Project/Radlex%26Clever/owlapi.xrdf (<class 'rdflib.graph.Graph'>)>

# %%
len(g)
# Out:
# 674842

# %%
for subj, pred, obj in g:
    if (subj, pred, obj) not in g:
        raise Exception("It better be!")

# %%
qry = """
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX radlex: <http://www.radlex.org/RID/#>

SELECT DISTINCT ?RID ?name ?synonym ?sub_name1 ?sub1_RID ?sub_name2 ?sub2_RID ?sub_name3 ?sub3_RID ?synonym1 ?synonym2 ?synonym3 ?synonym4 ?synonym5 ?synonym6 ?Is_A_name1 ?Is_A_name2 ?Is_A_name3
WHERE
{
 # ?term radlex:Preferred_name ?name .
 FILTER regex(?name,"lung",'i')
 # ?term rdfs:label ?RID .
 OPTIONAL{?term radlex:Synonym ?synonym  .}
 
 OPTIONAL{?term radlex:Has_Subtype ?Sub_type1  .
 # ?Sub_type1 radlex:Preferred_name ?sub_name1 .
 # ?Sub_type1 rdfs:label ?sub1_RID .
 
 OPTIONAL{?Sub_type1 radlex:Synonym ?synonym1  .}
 
 OPTIONAL{?Sub_type1 radlex:Has_Subtype ?Sub_type2  .
 # ?Sub_type2 radlex:Preferred_name ?sub_name2 .
 # ?Sub_type2 rdfs:label ?sub2_RID .
 
 OPTIONAL{?Sub_type2 radlex:Synonym ?synonym2  .}
 
 OPTIONAL{?Sub_type2 radlex:Has_Subtype ?Sub_type3  .
 # ?Sub_type3 radlex:Preferred_name ?sub_name3 .
 # ?Sub_type3 rdfs:label ?sub3_RID .
 
 OPTIONAL{?Sub_type3 radlex:Synonym ?synonym3  .}
 

 }}}}
 """

rows  = g.query(qry)

# %%
len(rows.bindings)
# Out:
# 154

# %%
res = [{str(k): str(v) for k, v in binding.items()} for binding in rows.bindings]

# %%
df = pd.DataFrame(res)
    
df.head(200)
# Out:
#           RID                                                            name  \
# 0    RID1303   upper lobe of right lung
# 1    RID1303   upper lobe of right lung
# 2    RID35299  incomplete border sign of lung
# 3    RID34938  region of surface of lung
# 4    RID34938  region of surface of lung
# 5    RID1313   medial segment of middle lobe of right lung
# 6    RID39056  lung mass
# 7    RID1327   upper lobe of left lung
# 8    RID1327   upper lobe of left lung
# 9    RID5339   respiratory broncholitis associated interstitial lung disease
# 10   RID5339   respiratory broncholitis associated interstitial lung disease
# 11   RID5339   respiratory broncholitis associated interstitial lung disease
# 12   RID5339   respiratory broncholitis associated interstitial lung disease
# 13   RID16726  neural network of lobe of lung
# 14   RID16726  neural network of lobe of lung
# 15   RID16726  neural network of lobe of lung
# 16   RID16726  neural network of lobe of lung
# 17   RID16726  neural network of lobe of lung
# 18   RID45686  lung cancer
# 19   RID35615  target sign of lung
# 20   RID16729  neural network of upper lobe of left lung
# 21   RID1290   anteromedial basal segment bronchus of lower lobe of left lung
# 22   RID16731  neural network of lower lobe of lung
# 23   RID16731  neural network of lower lobe of lung
# 24   RID1326   left lung
# 25   RID1359   axillary region of left lung
# 26   RID35739  lung parenchyma
# 27   RID34696  lower lobe of lung
# 28   RID34696  lower lobe of lung
# 29   RID34696  lower lobe of lung
# 30   RID34696  lower lobe of lung
# 31   RID1347   lung zone
# 32   RID1347   lung zone
# 33   RID1347   lung zone
# 34   RID1347   lung zone
# 35   RID1347   lung zone
# 36   RID1347   lung zone
# 37   RID1347   lung zone
# 38   RID1347   lung zone
# 39   RID1347   lung zone
# 40   RID1347   lung zone
# 41   RID1347   lung zone
# 42   RID1350   right upper lung zone
# 43   RID1329   apicoposterior segment of upper lobe of left lung
# 44   RID50136  Lung-RADS 1
# 45   RID16733  neural network of lower lobe of left lung
# 46   RID28940  subsegmental lymph node of right lung
# 47   RID35260  halo sign of lung
# 48   RID1339   superior segment of lower lobe of left lung
# 49   RID13437  lungs
# 50   RID1349   left upper lung zone
# 51   RID1338   lower lobe of left lung
# 52   RID1338   lower lobe of left lung
# 53   RID50135  Lung-RADS 0
# 54   RID50134  Lung-RADS assessment
# 55   RID50134  Lung-RADS assessment
# 56   RID50134  Lung-RADS assessment
# 57   RID50134  Lung-RADS assessment
# 58   RID50134  Lung-RADS assessment
# 59   RID50134  Lung-RADS assessment
# 60   RID50134  Lung-RADS assessment
# 61   RID50140  Lung-RADS 4B
# 62   RID1315   lower lobe of right lung
# 63   RID1315   lower lobe of right lung
# 64   RID50139  Lung-RADS 4A
# 65   RID1360   small lung component
# 66   RID3866   Madelung disease
# 67   RID28906  lung kernel
# 68   RID1352   left mid lung zone
# 69   RID10336  bremsstrahlung imaging
# 70   RID35306  intercostal bulging lung sign
# 71   RID1306   posterior segment of upper lobe of right lung
# 72   RID35088  cluster-of-grapes sign of lung
# 73   RID1311   lateral segment of middle lobe of right lung
# 74   RID1302   right lung
# 75   RID1320   anterior basal segment of lower lobe of right lung
# 76   RID1301   lung
# 77   RID1301   lung
# 78   RID35280  honeycomb lung
# 79   RID35280  honeycomb lung
# 80   RID1328   superior division of upper lobe of left lung
# 81   RID35359  Madelung deformity
# 82   RID1354   lower lung zone
# 83   RID1354   lower lung zone
# 84   RID34695  upper lobe of lung
# 85   RID34695  upper lobe of lung
# 86   RID34695  upper lobe of lung
# 87   RID34695  upper lobe of lung
# 88   RID1355   left lower lung zone
# 89   RID1310   middle lobe of lung
# 90   RID1310   middle lobe of lung
# 91   RID1310   middle lobe of lung
# 92   RID1351   mid lung zone
# 93   RID1351   mid lung zone
# 94   RID35688  wall sign of lung
# 95   RID16727  neural network of upper lobe of lung
# 96   RID16727  neural network of upper lobe of lung
# 97   RID16791  neural network of root of lung
# 98   RID34939  region of surface of lobe of lung
# 99   RID34939  region of surface of lobe of lung
# 100  RID34939  region of surface of lobe of lung
# 101  RID1440   cardiac notch of left lung
# 102  RID1348   upper lung zone
# 103  RID1348   upper lung zone
# 104  RID1324   posterior basal segment of lower lobe of right lung
# 105  RID16732  neural network of lower lobe of right lung
# 106  RID28584  apex of lung
# 107  RID28584  apex of lung
# 108  RID28584  apex of lung
# 109  RID1304   apical segment of upper lobe of right lung
# 110  RID1353   right mid lung zone
# 111  RID16730  neural network of middle lobe of lung
# 112  RID34694  lobe of lung
# 113  RID34694  lobe of lung
# 114  RID34694  lobe of lung
# 115  RID34694  lobe of lung
# 116  RID34694  lobe of lung
# 117  RID34694  lobe of lung
# 118  RID34694  lobe of lung
# 119  RID34694  lobe of lung
# 120  RID34694  lobe of lung
# 121  RID34694  lobe of lung
# 122  RID34694  lobe of lung
# 123  RID28941  subsegmental lymph node of left lung
# 124  RID1331   anterior segment of upper lobe of left lung
# 125  RID5328   chronic infiltrative lung disease
# 126  RID5328   chronic infiltrative lung disease
# 127  RID5328   chronic infiltrative lung disease
# 128  RID5328   chronic infiltrative lung disease
# 129  RID5328   chronic infiltrative lung disease
# 130  RID5328   chronic infiltrative lung disease
# 131  RID5328   chronic infiltrative lung disease
# 132  RID5328   chronic infiltrative lung disease
# 133  RID5328   chronic infiltrative lung disease
# 134  RID5328   chronic infiltrative lung disease
# 135  RID16728  neural network of upper lobe of right lung
# 136  RID50141  Lung-RADS 4X
# 137  RID1341   anteromedial basal segment of lower lobe of left lung
# 138  RID43251  subdivision of anterior margin of lung
# 139  RID43251  subdivision of anterior margin of lung
# 140  RID1308   anterior segment of upper lobe of right lung
# 141  RID1322   lateral basal segment of lower lobe of right lung
# 142  RID50138  Lung-RADS 3
# 143  RID1318   medial basal segment of lower lobe of right lung
# 144  RID43258  horizontal fissure of right lung
# 145  RID1343   lateral basal segment of lower lobe of left lung
# 146  RID1356   right lower lung zone
# 147  RID1316   superior segment of lower lobe of right lung
# 148  RID1358   axillary region of right lung
# 149  RID43250  anatomical line of lung
# 150  RID43250  anatomical line of lung
# 151  RID1345   posterior basal segment of lower lobe of left lung
# 152  RID50137  Lung-RADS 2
# 153  RID28799  interstitial lung disease
#
#      sub1_RID  sub2_RID  sub3_RID                                   sub_name1  \
# 0    NaN       NaN       NaN       NaN
# 1    NaN       NaN       NaN       NaN
# 2    NaN       NaN       NaN       NaN
# 3    RID34939  RID1372   RID1373   region of surface of lobe of lung
# 4    RID34939  RID1372   RID1378   region of surface of lobe of lung
# 5    NaN       NaN       NaN       NaN
# 6    NaN       NaN       NaN       NaN
# 7    NaN       NaN       NaN       NaN
# 8    NaN       NaN       NaN       NaN
# 9    NaN       NaN       NaN       NaN
# 10   NaN       NaN       NaN       NaN
# 11   NaN       NaN       NaN       NaN
# 12   NaN       NaN       NaN       NaN
# 13   RID16727  RID16729  NaN       neural network of upper lobe of lung
# 14   RID16727  RID16728  NaN       neural network of upper lobe of lung
# 15   RID16731  RID16732  NaN       neural network of lower lobe of lung
# 16   RID16731  RID16733  NaN       neural network of lower lobe of lung
# 17   RID16730  NaN       NaN       neural network of middle lobe of lung
# 18   NaN       NaN       NaN       NaN
# 19   NaN       NaN       NaN       NaN
# 20   NaN       NaN       NaN       NaN
# 21   NaN       NaN       NaN       NaN
# 22   RID16732  NaN       NaN       neural network of lower lobe of right lung
# 23   RID16733  NaN       NaN       neural network of lower lobe of left lung
# 24   NaN       NaN       NaN       NaN
# 25   NaN       NaN       NaN       NaN
# 26   NaN       NaN       NaN       NaN
# 27   RID1315   NaN       NaN       lower lobe of right lung
# 28   RID1315   NaN       NaN       lower lobe of right lung
# 29   RID1338   NaN       NaN       lower lobe of left lung
# 30   RID1338   NaN       NaN       lower lobe of left lung
# 31   RID1351   RID1353   NaN       mid lung zone
# 32   RID1351   RID1352   NaN       mid lung zone
# 33   RID28584  NaN       NaN       apex of lung
# 34   RID28584  NaN       NaN       apex of lung
# 35   RID28584  NaN       NaN       apex of lung
# 36   RID1354   RID1356   NaN       lower lung zone
# 37   RID1354   RID1355   NaN       lower lung zone
# 38   RID1357   RID1359   NaN       axillary region
# 39   RID1357   RID1358   NaN       axillary region
# 40   RID1348   RID1349   NaN       upper lung zone
# 41   RID1348   RID1350   NaN       upper lung zone
# 42   NaN       NaN       NaN       NaN
# 43   NaN       NaN       NaN       NaN
# 44   NaN       NaN       NaN       NaN
# 45   NaN       NaN       NaN       NaN
# 46   NaN       NaN       NaN       NaN
# 47   NaN       NaN       NaN       NaN
# 48   NaN       NaN       NaN       NaN
# 49   NaN       NaN       NaN       NaN
# 50   NaN       NaN       NaN       NaN
# 51   NaN       NaN       NaN       NaN
# 52   NaN       NaN       NaN       NaN
# 53   NaN       NaN       NaN       NaN
# 54   RID50138  NaN       NaN       Lung-RADS 3
# 55   RID50139  NaN       NaN       Lung-RADS 4A
# 56   RID50141  NaN       NaN       Lung-RADS 4X
# 57   RID50136  NaN       NaN       Lung-RADS 1
# 58   RID50140  NaN       NaN       Lung-RADS 4B
# 59   RID50135  NaN       NaN       Lung-RADS 0
# 60   RID50137  NaN       NaN       Lung-RADS 2
# 61   NaN       NaN       NaN       NaN
# 62   NaN       NaN       NaN       NaN
# 63   NaN       NaN       NaN       NaN
# 64   NaN       NaN       NaN       NaN
# 65   RID1361   NaN       NaN       secondary pulmonary lobule
# 66   NaN       NaN       NaN       NaN
# 67   NaN       NaN       NaN       NaN
# 68   NaN       NaN       NaN       NaN
# 69   NaN       NaN       NaN       NaN
# 70   NaN       NaN       NaN       NaN
# 71   NaN       NaN       NaN       NaN
# 72   NaN       NaN       NaN       NaN
# 73   NaN       NaN       NaN       NaN
# 74   NaN       NaN       NaN       NaN
# 75   NaN       NaN       NaN       NaN
# 76   RID1326   NaN       NaN       left lung
# 77   RID1302   NaN       NaN       right lung
# 78   NaN       NaN       NaN       NaN
# 79   NaN       NaN       NaN       NaN
# 80   NaN       NaN       NaN       NaN
# 81   NaN       NaN       NaN       NaN
# 82   RID1356   NaN       NaN       right lower lung zone
# 83   RID1355   NaN       NaN       left lower lung zone
# 84   RID1327   NaN       NaN       upper lobe of left lung
# 85   RID1327   NaN       NaN       upper lobe of left lung
# 86   RID1303   NaN       NaN       upper lobe of right lung
# 87   RID1303   NaN       NaN       upper lobe of right lung
# 88   NaN       NaN       NaN       NaN
# 89   NaN       NaN       NaN       NaN
# 90   NaN       NaN       NaN       NaN
# 91   NaN       NaN       NaN       NaN
# 92   RID1353   NaN       NaN       right mid lung zone
# 93   RID1352   NaN       NaN       left mid lung zone
# 94   NaN       NaN       NaN       NaN
# 95   RID16729  NaN       NaN       neural network of upper lobe of left lung
# 96   RID16728  NaN       NaN       neural network of upper lobe of right lung
# 97   NaN       NaN       NaN       NaN
# 98   RID1372   RID1373   RID1376   pleural fissure
# 99   RID1372   RID1373   RID1374   pleural fissure
# 100  RID1372   RID1378   RID1379   pleural fissure
# 101  NaN       NaN       NaN       NaN
# 102  RID1349   NaN       NaN       left upper lung zone
# 103  RID1350   NaN       NaN       right upper lung zone
# 104  NaN       NaN       NaN       NaN
# 105  NaN       NaN       NaN       NaN
# 106  NaN       NaN       NaN       NaN
# 107  NaN       NaN       NaN       NaN
# 108  NaN       NaN       NaN       NaN
# 109  NaN       NaN       NaN       NaN
# 110  NaN       NaN       NaN       NaN
# 111  NaN       NaN       NaN       NaN
# 112  RID34696  RID1315   NaN       lower lobe of lung
# 113  RID34696  RID1315   NaN       lower lobe of lung
# 114  RID34696  RID1338   NaN       lower lobe of lung
# 115  RID34696  RID1338   NaN       lower lobe of lung
# 116  RID1310   NaN       NaN       middle lobe of lung
# 117  RID1310   NaN       NaN       middle lobe of lung
# 118  RID1310   NaN       NaN       middle lobe of lung
# 119  RID34695  RID1327   NaN       upper lobe of lung
# 120  RID34695  RID1327   NaN       upper lobe of lung
# 121  RID34695  RID1303   NaN       upper lobe of lung
# 122  RID34695  RID1303   NaN       upper lobe of lung
# 123  NaN       NaN       NaN       NaN
# 124  NaN       NaN       NaN       NaN
# 125  RID5329   RID28518  RID5335   interstitial pneumonia
# 126  RID5329   RID28518  RID5335   interstitial pneumonia
# 127  RID5329   RID28518  RID5335   interstitial pneumonia
# 128  RID5329   RID5330   NaN       interstitial pneumonia
# 129  RID5329   RID5331   NaN       interstitial pneumonia
# 130  RID5329   RID5342   NaN       interstitial pneumonia
# 131  RID5329   RID5341   NaN       interstitial pneumonia
# 132  RID5329   RID28515  NaN       interstitial pneumonia
# 133  RID5329   RID5333   NaN       interstitial pneumonia
# 134  RID5329   RID28508  RID28836  interstitial pneumonia
# 135  NaN       NaN       NaN       NaN
# 136  NaN       NaN       NaN       NaN
# 137  NaN       NaN       NaN       NaN
# 138  RID1440   NaN       NaN       cardiac notch of left lung
# 139  RID1434   NaN       NaN       anterior junction line
# 140  NaN       NaN       NaN       NaN
# 141  NaN       NaN       NaN       NaN
# 142  NaN       NaN       NaN       NaN
# 143  NaN       NaN       NaN       NaN
# 144  NaN       NaN       NaN       NaN
# 145  NaN       NaN       NaN       NaN
# 146  NaN       NaN       NaN       NaN
# 147  NaN       NaN       NaN       NaN
# 148  NaN       NaN       NaN       NaN
# 149  RID43251  RID1440   NaN       subdivision of anterior margin of lung
# 150  RID43251  RID1434   NaN       subdivision of anterior margin of lung
# 151  NaN       NaN       NaN       NaN
# 152  NaN       NaN       NaN       NaN
# 153  RID34650  NaN       NaN       pulmonary alveolar proteinosis
#
#                                       sub_name2  \
# 0    NaN
# 1    NaN
# 2    NaN
# 3    pleural fissure
# 4    pleural fissure
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   neural network of upper lobe of left lung
# 14   neural network of upper lobe of right lung
# 15   neural network of lower lobe of right lung
# 16   neural network of lower lobe of left lung
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# 30   NaN
# 31   right mid lung zone
# 32   left mid lung zone
# 33   NaN
# 34   NaN
# 35   NaN
# 36   right lower lung zone
# 37   left lower lung zone
# 38   axillary region of left lung
# 39   axillary region of right lung
# 40   left upper lung zone
# 41   right upper lung zone
# 42   NaN
# 43   NaN
# 44   NaN
# 45   NaN
# 46   NaN
# 47   NaN
# 48   NaN
# 49   NaN
# 50   NaN
# 51   NaN
# 52   NaN
# 53   NaN
# 54   NaN
# 55   NaN
# 56   NaN
# 57   NaN
# 58   NaN
# 59   NaN
# 60   NaN
# 61   NaN
# 62   NaN
# 63   NaN
# 64   NaN
# 65   NaN
# 66   NaN
# 67   NaN
# 68   NaN
# 69   NaN
# 70   NaN
# 71   NaN
# 72   NaN
# 73   NaN
# 74   NaN
# 75   NaN
# 76   NaN
# 77   NaN
# 78   NaN
# 79   NaN
# 80   NaN
# 81   NaN
# 82   NaN
# 83   NaN
# 84   NaN
# 85   NaN
# 86   NaN
# 87   NaN
# 88   NaN
# 89   NaN
# 90   NaN
# 91   NaN
# 92   NaN
# 93   NaN
# 94   NaN
# 95   NaN
# 96   NaN
# 97   NaN
# 98   right pleural fissure
# 99   right pleural fissure
# 100  left pleural fissure
# 101  NaN
# 102  NaN
# 103  NaN
# 104  NaN
# 105  NaN
# 106  NaN
# 107  NaN
# 108  NaN
# 109  NaN
# 110  NaN
# 111  NaN
# 112  lower lobe of right lung
# 113  lower lobe of right lung
# 114  lower lobe of left lung
# 115  lower lobe of left lung
# 116  NaN
# 117  NaN
# 118  NaN
# 119  upper lobe of left lung
# 120  upper lobe of left lung
# 121  upper lobe of right lung
# 122  upper lobe of right lung
# 123  NaN
# 124  NaN
# 125  organizing pneumonia
# 126  organizing pneumonia
# 127  organizing pneumonia
# 128  acute interstitial pneumonia
# 129  desquamative interstitial pneumonia
# 130  lymphocytic interstitial pneumonia
# 131  nonspecific interstitial pneumonia
# 132  lymphoid interstitial pneumonia
# 133  usual interstitial pneumonia
# 134  chronic fibrosing interstitial pneumonia
# 135  NaN
# 136  NaN
# 137  NaN
# 138  NaN
# 139  NaN
# 140  NaN
# 141  NaN
# 142  NaN
# 143  NaN
# 144  NaN
# 145  NaN
# 146  NaN
# 147  NaN
# 148  NaN
# 149  cardiac notch of left lung
# 150  anterior junction line
# 151  NaN
# 152  NaN
# 153  NaN
#
#                             sub_name3  \
# 0    NaN
# 1    NaN
# 2    NaN
# 3    right pleural fissure
# 4    left pleural fissure
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# 30   NaN
# 31   NaN
# 32   NaN
# 33   NaN
# 34   NaN
# 35   NaN
# 36   NaN
# 37   NaN
# 38   NaN
# 39   NaN
# 40   NaN
# 41   NaN
# 42   NaN
# 43   NaN
# 44   NaN
# 45   NaN
# 46   NaN
# 47   NaN
# 48   NaN
# 49   NaN
# 50   NaN
# 51   NaN
# 52   NaN
# 53   NaN
# 54   NaN
# 55   NaN
# 56   NaN
# 57   NaN
# 58   NaN
# 59   NaN
# 60   NaN
# 61   NaN
# 62   NaN
# 63   NaN
# 64   NaN
# 65   NaN
# 66   NaN
# 67   NaN
# 68   NaN
# 69   NaN
# 70   NaN
# 71   NaN
# 72   NaN
# 73   NaN
# 74   NaN
# 75   NaN
# 76   NaN
# 77   NaN
# 78   NaN
# 79   NaN
# 80   NaN
# 81   NaN
# 82   NaN
# 83   NaN
# 84   NaN
# 85   NaN
# 86   NaN
# 87   NaN
# 88   NaN
# 89   NaN
# 90   NaN
# 91   NaN
# 92   NaN
# 93   NaN
# 94   NaN
# 95   NaN
# 96   NaN
# 97   NaN
# 98   right minor fissure
# 99   right major fissure
# 100  left major fissure
# 101  NaN
# 102  NaN
# 103  NaN
# 104  NaN
# 105  NaN
# 106  NaN
# 107  NaN
# 108  NaN
# 109  NaN
# 110  NaN
# 111  NaN
# 112  NaN
# 113  NaN
# 114  NaN
# 115  NaN
# 116  NaN
# 117  NaN
# 118  NaN
# 119  NaN
# 120  NaN
# 121  NaN
# 122  NaN
# 123  NaN
# 124  NaN
# 125  cryptogenic organizing pneumonia
# 126  cryptogenic organizing pneumonia
# 127  cryptogenic organizing pneumonia
# 128  NaN
# 129  NaN
# 130  NaN
# 131  NaN
# 132  NaN
# 133  NaN
# 134  idiopathic pulmonary fibrosis
# 135  NaN
# 136  NaN
# 137  NaN
# 138  NaN
# 139  NaN
# 140  NaN
# 141  NaN
# 142  NaN
# 143  NaN
# 144  NaN
# 145  NaN
# 146  NaN
# 147  NaN
# 148  NaN
# 149  NaN
# 150  NaN
# 151  NaN
# 152  NaN
# 153  NaN
#
#                                                            synonym  \
# 0    right upper lobe
# 1    RUL
# 2    NaN
# 3    NaN
# 4    NaN
# 5    S5 segment of middle lobe of right lung
# 6    mass
# 7    LUL
# 8    left upper lobe
# 9    respiratory broncholitis-associated interstitial lung disease
# 10   respiratory broncholitis
# 11   RB-ILD
# 12   respiratory bronchiolitis-interstitial lung disease
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   S7+8 bronchus of lower lobe of left lung
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# 30   NaN
# 31   NaN
# 32   NaN
# 33   NaN
# 34   NaN
# 35   NaN
# 36   NaN
# 37   NaN
# 38   NaN
# 39   NaN
# 40   NaN
# 41   NaN
# 42   NaN
# 43   S1+2 segment of upper lobe of left lung
# 44   NaN
# 45   NaN
# 46   14R thoracic lymph node
# 47   CT halo sign
# 48   S6 segment of lower lobe of left lung
# 49   NaN
# 50   NaN
# 51   left lower lobe
# 52   LLL
# 53   NaN
# 54   NaN
# 55   NaN
# 56   NaN
# 57   NaN
# 58   NaN
# 59   NaN
# 60   NaN
# 61   NaN
# 62   right lower lobe
# 63   RLL
# 64   NaN
# 65   NaN
# 66   benign symmetric lipomatosis
# 67   NaN
# 68   NaN
# 69   NaN
# 70   NaN
# 71   S2 segment of upper lobe of right lung
# 72   cluster of grapes sign of lung
# 73   S4 segment of middle lobe of right lung
# 74   NaN
# 75   S8 segment of lower lobe of right lung
# 76   NaN
# 77   NaN
# 78   honeycombing
# 79   end-stage lung disease
# 80   NaN
# 81   NaN
# 82   NaN
# 83   NaN
# 84   NaN
# 85   NaN
# 86   NaN
# 87   NaN
# 88   NaN
# 89   right middle lobe
# 90   middle lobe of right lung
# 91   RML
# 92   NaN
# 93   NaN
# 94   lung wall sign
# 95   NaN
# 96   NaN
# 97   NaN
# 98   NaN
# 99   NaN
# 100  NaN
# 101  cardiac incisura
# 102  NaN
# 103  NaN
# 104  S10 segment of lower lobe of right lung
# 105  NaN
# 106  pulm apex
# 107  lung apex
# 108  pulmonary apex
# 109  S1 segment of upper lobe of right lung
# 110  NaN
# 111  NaN
# 112  NaN
# 113  NaN
# 114  NaN
# 115  NaN
# 116  NaN
# 117  NaN
# 118  NaN
# 119  NaN
# 120  NaN
# 121  NaN
# ...
# 26   NaN                        NaN
# 27   right lower lobe           NaN
# 28   RLL                        NaN
# 29   left lower lobe            NaN
# 30   LLL                        NaN
# 31   NaN                        NaN
# 32   NaN                        NaN
# 33   pulm apex                  NaN
# 34   lung apex                  NaN
# 35   pulmonary apex             NaN
# 36   NaN                        NaN
# 37   NaN                        NaN
# 38   NaN                        NaN
# 39   NaN                        NaN
# 40   NaN                        NaN
# 41   NaN                        NaN
# 42   NaN                        NaN
# 43   NaN                        NaN
# 44   NaN                        NaN
# 45   NaN                        NaN
# 46   NaN                        NaN
# 47   NaN                        NaN
# 48   NaN                        NaN
# 49   NaN                        NaN
# 50   NaN                        NaN
# 51   NaN                        NaN
# 52   NaN                        NaN
# 53   NaN                        NaN
# 54   NaN                        NaN
# 55   NaN                        NaN
# 56   NaN                        NaN
# 57   NaN                        NaN
# 58   NaN                        NaN
# 59   NaN                        NaN
# 60   NaN                        NaN
# 61   NaN                        NaN
# 62   NaN                        NaN
# 63   NaN                        NaN
# 64   NaN                        NaN
# 65   NaN                        NaN
# 66   NaN                        NaN
# 67   NaN                        NaN
# 68   NaN                        NaN
# 69   NaN                        NaN
# 70   NaN                        NaN
# 71   NaN                        NaN
# 72   NaN                        NaN
# 73   NaN                        NaN
# 74   NaN                        NaN
# 75   NaN                        NaN
# 76   NaN                        NaN
# 77   NaN                        NaN
# 78   NaN                        NaN
# 79   NaN                        NaN
# 80   NaN                        NaN
# 81   NaN                        NaN
# 82   NaN                        NaN
# 83   NaN                        NaN
# 84   LUL                        NaN
# 85   left upper lobe            NaN
# 86   right upper lobe           NaN
# 87   RUL                        NaN
# 88   NaN                        NaN
# 89   NaN                        NaN
# 90   NaN                        NaN
# 91   NaN                        NaN
# 92   NaN                        NaN
# 93   NaN                        NaN
# 94   NaN                        NaN
# 95   NaN                        NaN
# 96   NaN                        NaN
# 97   NaN                        NaN
# 98   pulmonary fissure          NaN
# 99   pulmonary fissure          NaN
# 100  pulmonary fissure          NaN
# 101  NaN                        NaN
# 102  NaN                        NaN
# 103  NaN                        NaN
# 104  NaN                        NaN
# 105  NaN                        NaN
# 106  NaN                        NaN
# 107  NaN                        NaN
# 108  NaN                        NaN
# 109  NaN                        NaN
# 110  NaN                        NaN
# 111  NaN                        NaN
# 112  NaN                        right lower lobe
# 113  NaN                        RLL
# 114  NaN                        left lower lobe
# 115  NaN                        LLL
# 116  right middle lobe          NaN
# 117  middle lobe of right lung  NaN
# 118  RML                        NaN
# 119  NaN                        LUL
# 120  NaN                        left upper lobe
# 121  NaN                        right upper lobe
# 122  NaN                        RUL
# 123  NaN                        NaN
# 124  NaN                        NaN
# 125  NaN                        NaN
# 126  NaN                        NaN
# 127  NaN                        NaN
# 128  NaN                        NaN
# 129  NaN                        NaN
# 130  NaN                        NaN
# 131  NaN                        NaN
# 132  NaN                        NaN
# 133  NaN                        NaN
# 134  NaN                        NaN
# 135  NaN                        NaN
# 136  NaN                        NaN
# 137  NaN                        NaN
# 138  cardiac incisura           NaN
# 139  anterior mediastinal line  NaN
# 140  NaN                        NaN
# 141  NaN                        NaN
# 142  NaN                        NaN
# 143  NaN                        NaN
# 144  NaN                        NaN
# 145  NaN                        NaN
# 146  NaN                        NaN
# 147  NaN                        NaN
# 148  NaN                        NaN
# 149  NaN                        cardiac incisura
# 150  NaN                        anterior mediastinal line
# 151  NaN                        NaN
# 152  NaN                        NaN
# 153  NaN                        NaN
#
#                                           synonym3
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# 30   NaN
# 31   NaN
# 32   NaN
# 33   NaN
# 34   NaN
# 35   NaN
# 36   NaN
# 37   NaN
# 38   NaN
# 39   NaN
# 40   NaN
# 41   NaN
# 42   NaN
# 43   NaN
# 44   NaN
# 45   NaN
# 46   NaN
# 47   NaN
# 48   NaN
# 49   NaN
# 50   NaN
# 51   NaN
# 52   NaN
# 53   NaN
# 54   NaN
# 55   NaN
# 56   NaN
# 57   NaN
# 58   NaN
# 59   NaN
# 60   NaN
# 61   NaN
# 62   NaN
# 63   NaN
# 64   NaN
# 65   NaN
# 66   NaN
# 67   NaN
# 68   NaN
# 69   NaN
# 70   NaN
# 71   NaN
# 72   NaN
# 73   NaN
# 74   NaN
# 75   NaN
# 76   NaN
# 77   NaN
# 78   NaN
# 79   NaN
# 80   NaN
# 81   NaN
# 82   NaN
# 83   NaN
# 84   NaN
# 85   NaN
# 86   NaN
# 87   NaN
# 88   NaN
# 89   NaN
# 90   NaN
# 91   NaN
# 92   NaN
# 93   NaN
# 94   NaN
# 95   NaN
# 96   NaN
# 97   NaN
# 98   right horizontal interlobar fissure
# 99   right oblique interlobar fissure
# 100  left oblique interlobar fissure
# 101  NaN
# 102  NaN
# 103  NaN
# 104  NaN
# 105  NaN
# 106  NaN
# 107  NaN
# 108  NaN
# 109  NaN
# 110  NaN
# 111  NaN
# 112  NaN
# 113  NaN
# 114  NaN
# 115  NaN
# 116  NaN
# 117  NaN
# 118  NaN
# 119  NaN
# 120  NaN
# 121  NaN
# 122  NaN
# 123  NaN
# 124  NaN
# 125  COP
# 126  BOOP
# 127  bronchiolitis obliterans organizing pneumonia
# 128  NaN
# 129  NaN
# 130  NaN
# 131  NaN
# 132  NaN
# 133  NaN
# 134  NaN
# 135  NaN
# 136  NaN
# 137  NaN
# 138  NaN
# 139  NaN
# 140  NaN
# 141  NaN
# 142  NaN
# 143  NaN
# 144  NaN
# 145  NaN
# 146  NaN
# 147  NaN
# 148  NaN
# 149  NaN
# 150  NaN
# 151  NaN
# 152  NaN
# 153  NaN

# %%
Lst = [df['name'].tolist(), df['sub_name1'].tolist(), df['sub_name2'].tolist(), df['sub_name3'].tolist(), df['synonym'].tolist(), df['synonym1'].tolist(), df['synonym2'].tolist(), df['synonym3'].tolist()]

# %%
print(Lst)
# Out:
# [['upper lobe of right lung', 'upper lobe of right lung', 'incomplete border sign of lung', 'region of surface of lung', 'region of surface of lung', 'medial segment of middle lobe of right lung', 'lung mass', 'upper lobe of left lung', 'upper lobe of left lung', 'respiratory broncholitis associated interstitial lung disease', 'respiratory broncholitis associated interstitial lung disease', 'respiratory broncholitis associated interstitial lung disease', 'respiratory broncholitis associated interstitial lung disease', 'neural network of lobe of lung', 'neural network of lobe of lung', 'neural network of lobe of lung', 'neural network of lobe of lung', 'neural network of lobe of lung', 'lung cancer', 'target sign of lung', 'neural network of upper lobe of left lung', 'anteromedial basal segment bronchus of lower lobe of left lung', 'neural network of lower lobe of lung', 'neural network of lower lobe of lung', 'left lung', 'axillary region of left lung', 'lung parenchyma', 'lower lobe of lung', 'lower lobe of lung', 'lower lobe of lung', 'lower lobe of lung', 'lung zone', 'lung zone', 'lung zone', 'lung zone', 'lung zone', 'lung zone', 'lung zone', 'lung zone', 'lung zone', 'lung zone', 'lung zone', 'right upper lung zone', 'apicoposterior segment of upper lobe of left lung', 'Lung-RADS 1', 'neural network of lower lobe of left lung', 'subsegmental lymph node of right lung', 'halo sign of lung', 'superior segment of lower lobe of left lung', 'lungs', 'left upper lung zone', 'lower lobe of left lung', 'lower lobe of left lung', 'Lung-RADS 0', 'Lung-RADS assessment', 'Lung-RADS assessment', 'Lung-RADS assessment', 'Lung-RADS assessment', 'Lung-RADS assessment', 'Lung-RADS assessment', 'Lung-RADS assessment', 'Lung-RADS 4B', 'lower lobe of right lung', 'lower lobe of right lung', 'Lung-RADS 4A', 'small lung component', 'Madelung disease', 'lung kernel', 'left mid lung zone', 'bremsstrahlung imaging', 'intercostal bulging lung sign', 'posterior segment of upper lobe of right lung', 'cluster-of-grapes sign of lung', 'lateral segment of middle lobe of right lung', 'right lung', 'anterior basal segment of lower lobe of right lung', 'lung', 'lung', 'honeycomb lung', 'honeycomb lung', 'superior division of upper lobe of left lung', 'Madelung deformity', 'lower lung zone', 'lower lung zone', 'upper lobe of lung', 'upper lobe of lung', 'upper lobe of lung', 'upper lobe of lung', 'left lower lung zone', 'middle lobe of lung', 'middle lobe of lung', 'middle lobe of lung', 'mid lung zone', 'mid lung zone', 'wall sign of lung', 'neural network of upper lobe of lung', 'neural network of upper lobe of lung', 'neural network of root of lung', 'region of surface of lobe of lung', 'region of surface of lobe of lung', 'region of surface of lobe of lung', 'cardiac notch of left lung', 'upper lung zone', 'upper lung zone', 'posterior basal segment of lower lobe of right lung', 'neural network of lower lobe of right lung', 'apex of lung', 'apex of lung', 'apex of lung', 'apical segment of upper lobe of right lung', 'right mid lung zone', 'neural network of middle lobe of lung', 'lobe of lung', 'lobe of lung', 'lobe of lung', 'lobe of lung', 'lobe of lung', 'lobe of lung', 'lobe of lung', 'lobe of lung', 'lobe of lung', 'lobe of lung', 'lobe of lung', 'subsegmental lymph node of left lung', 'anterior segment of upper lobe of left lung', 'chronic infiltrative lung disease', 'chronic infiltrative lung disease', 'chronic infiltrative lung disease', 'chronic infiltrative lung disease', 'chronic infiltrative lung disease', 'chronic infiltrative lung disease', 'chronic infiltrative lung disease', 'chronic infiltrative lung disease', 'chronic infiltrative lung disease', 'chronic infiltrative lung disease', 'neural network of upper lobe of right lung', 'Lung-RADS 4X', 'anteromedial basal segment of lower lobe of left lung', 'subdivision of anterior margin of lung', 'subdivision of anterior margin of lung', 'anterior segment of upper lobe of right lung', 'later ...

# %%
Lung_values = []
for lists in Lst:
    for string in lists:
        if str(string) == 'nan':
            pass
        else:
            Lung_values.append(string)

Lung_values = list(set(Lung_values))
print(Lung_values)
# Out:
# ['anatomical line of lung', 'lower lobe of left lung', 'apex of lung', 'axillary region of right lung', 'halo sign of lung', 'anterior segment of upper lobe of left lung', 'posterior basal segment of lower lobe of left lung', 'S9 segment of lower lobe of right lung', 'lung zone', 'left major fissure', 'target sign of lung', 'medial segment of middle lobe of right lung', 'axillary region of left lung', 'Lung-RADS 2', 'CT halo sign', 'secondary pulmonary lobule', 'neural network of lower lobe of lung', 'horizontal fissure of right lung', 'lower lobe of right lung', 'lower lobe of lung', 'right lung', 'lower lung zone', 'cluster of grapes sign of lung', 'lobe of lung', 'subdivision of anterior margin of lung', 'S1+2 segment of upper lobe of left lung', 'right lower lobe', 'Lung-RADS 4B', 'left lower lobe', 'S7+8 segment of lower lobe of left lung', 'lung kernel', 'upper lobe of right lung', 'apical segment of upper lobe of right lung', 'lung cancer', 'lung parenchyma', 'Lung-RADS 4X', 'chronic infiltrative lung disease', 'interstitial lung disease', 'right upper lung zone', 'idiopathic pulmonary fibrosis', 'superior division of upper lobe of left lung', '14R thoracic lymph node', 'mid lung zone', 'neural network of root of lung', 'Lung-RADS 3', 'anterior segment of upper lobe of right lung', 'benign symmetric lipomatosis', 'left lung', 'neural network of upper lobe of lung', 'cryptogenic organizing pneumonia', 'left mid lung zone', 'RML', 'RB-ILD', 'S4 segment of middle lobe of right lung', 'S7 segment of lower lobe of right lung', 'right oblique interlobar fissure', 'respiratory bronchiolitis-interstitial lung disease', 'upper lobe of lung', 'RLL', 'left upper lung zone', 'pulm apex', 'right mid lung zone', 'left upper lobe', 'neural network of lobe of lung', 'left pleural fissure', 'honeycomb lung', 'respiratory broncholitis', 'subsegmental lymph node of right lung', 'neural network of lower lobe of right lung', 'small lung component', 'S3 segment of upper lobe of right lung', 'lymphoid interstitial pneumonia', 'organizing pneumonia', 'region of surface of lung', 'RUL', 'pulmonary fissure', 'BOOP', 'Madelung deformity', 'Lung-RADS assessment', 'S5 segment of middle lobe of right lung', 'anterior junction line', 'respiratory broncholitis associated interstitial lung disease', 'medial basal segment of lower lobe of right lung', 'end-stage lung disease', 'upper lobe of left lung', 'neural network of upper lobe of left lung', 'axillary region', 'lung wall sign', 'right middle lobe', 'intercostal bulging lung sign', 'incomplete border sign of lung', 'interstitial pneumonia', 'right lower lung zone', 'right upper lobe', 'superior segment of lower lobe of left lung', 'Madelung disease', 'Lung-RADS 0', 'interstitial disease', 'chronic fibrosing interstitial pneumonia', 'cardiac incisura', 'bronchiolitis obliterans organizing pneumonia', 'S7+8 bronchus of lower lobe of left lung', 'lung apex', 'acute interstitial pneumonia', 'superior segment of lower lobe of right lung', 'neural network of lower lobe of left lung', 'lungs', 'Lung-RADS 1', 'lymphocytic interstitial pneumonia', '14L thoracic lymph node', 'left lower lung zone', 'LLL', 'subsegmental lymph node of left lung', 'S10 segment of lower lobe of right lung', 'neural network of upper lobe of right lung', 'honeycombing', 'COP', 'cardiac notch of left lung', 'anteromedial basal segment of lower lobe of left lung', 'lung', 'upper lung zone', 'right pleural fissure', 'pulmonary apex', 'S8 segment of lower lobe of right lung', 'desquamative interstitial pneumonia', 'S6 segment of lower lobe of left lung', 'anterior basal segment of lower lobe of right lung', 'lateral basal segment of lower lobe of right lung', 'wall sign of lung', 'mass', 'S9 segment of lower lobe of left lung', 'S1 segment of upper lobe of right lung', 'anteromedial basal segment bronchus of lower lobe of left lung', 'cluster-of-grapes sign of lung', 'neural network of middle lobe of lung', 'lung mass', 'S3 segment of ...
