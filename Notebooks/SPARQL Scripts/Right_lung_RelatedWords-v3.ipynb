# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 500)

# %%
from SPARQLWrapper import SPARQLWrapper, CSV
from io import StringIO

# %%
sparql = SPARQLWrapper("http://localhost:8890/sparql")

# %% [markdown]
# Three SPARQL optimizations:
#  - Internal query generates a list of RIDs which we are interested on:
#  ```SPARQL
#  SELECT ?rid ?seed_name WHERE {
#    VALUES ?seed { <http://www.radlex.org/RID/#RID1302> <http://www.radlex.org/RID/#RID1326> }
#    ?seed radlex:Preferred_name ?seed_name .
#    ?seed radlex:Has_Part{1,2} ?rid
#  }
#  ```
#  The `radlex:Has_Part{1,2}` syntax allows us to fetch children and grand children of the ID of interest. In this case, the sub-parts and sub-sub-parts of RID1302 (right lung). See [sparql documentation](https://www.w3.org/TR/sparql11-property-paths/) for more details.
#  - The `VALUES` clause allows us to use several values as our starting points (in this case `http://www.radlex.org/RID/#RID1302>` and `<http://www.radlex.org/RID/#RID1326` -- the URIs for `left lung` and `right lung`
#  - Then external query finds the `preferred_name` and `synonym` of the IDs of interest.

# %%
qry = """
PREFIX radlex: <http://www.radlex.org/RID/#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT ?rid ?seed_name ?name ?synonym 
WHERE {
  {
    SELECT ?rid ?seed_name WHERE {
      VALUES ?seed { <http://www.radlex.org/RID/#RID1302> <http://www.radlex.org/RID/#RID1326> }
      # ?seed radlex:Preferred_name ?seed_name .
      # ?seed radlex:Has_Part{1,2} ?rid
    }
  } .
  # ?rid radlex:Preferred_name ?name .
  OPTIONAL{?rid radlex:Synonym ?synonym  }
} ORDER BY ?seed_name
"""

# %%
sparql.setQuery(qry)
sparql.setReturnFormat(CSV)
res = sparql.queryAndConvert()
resAsStr = res.decode('utf-8')

# %%
df = pd.read_csv(StringIO(resAsStr))
df = df.fillna('')
df.head(200)
# Out:
#                                    rid   seed_name  \
# 0   http://www.radlex.org/RID/#RID1338  left lung
# 1   http://www.radlex.org/RID/#RID1338  left lung
# 2   http://www.radlex.org/RID/#RID1339  left lung
# 3   http://www.radlex.org/RID/#RID1341  left lung
# 4   http://www.radlex.org/RID/#RID1327  left lung
# 5   http://www.radlex.org/RID/#RID1327  left lung
# 6   http://www.radlex.org/RID/#RID1343  left lung
# 7   http://www.radlex.org/RID/#RID1345  left lung
# 8   http://www.radlex.org/RID/#RID1328  left lung
# 9   http://www.radlex.org/RID/#RID1349  left lung
# 10  http://www.radlex.org/RID/#RID1355  left lung
# 11  http://www.radlex.org/RID/#RID1333  left lung
# 12  http://www.radlex.org/RID/#RID1352  left lung
# 13  http://www.radlex.org/RID/#RID1359  left lung
# 14  http://www.radlex.org/RID/#RID1303  right lung
# 15  http://www.radlex.org/RID/#RID1303  right lung
# 16  http://www.radlex.org/RID/#RID1304  right lung
# 17  http://www.radlex.org/RID/#RID1306  right lung
# 18  http://www.radlex.org/RID/#RID1308  right lung
# 19  http://www.radlex.org/RID/#RID1315  right lung
# 20  http://www.radlex.org/RID/#RID1315  right lung
# 21  http://www.radlex.org/RID/#RID1318  right lung
# 22  http://www.radlex.org/RID/#RID1310  right lung
# 23  http://www.radlex.org/RID/#RID1310  right lung
# 24  http://www.radlex.org/RID/#RID1310  right lung
# 25  http://www.radlex.org/RID/#RID1311  right lung
# 26  http://www.radlex.org/RID/#RID1313  right lung
# 27  http://www.radlex.org/RID/#RID1316  right lung
# 28  http://www.radlex.org/RID/#RID1320  right lung
# 29  http://www.radlex.org/RID/#RID1322  right lung
# 30  http://www.radlex.org/RID/#RID1324  right lung
# 31  http://www.radlex.org/RID/#RID1349  right lung
# 32  http://www.radlex.org/RID/#RID1350  right lung
# 33  http://www.radlex.org/RID/#RID1353  right lung
# 34  http://www.radlex.org/RID/#RID1356  right lung
# 35  http://www.radlex.org/RID/#RID1358  right lung
#
#                                                      name  \
# 0   lower lobe of left lung
# 1   lower lobe of left lung
# 2   superior segment of lower lobe of left lung
# 3   anteromedial basal segment of lower lobe of left lung
# 4   upper lobe of left lung
# 5   upper lobe of left lung
# 6   lateral basal segment of lower lobe of left lung
# 7   posterior basal segment of lower lobe of left lung
# 8   superior division of upper lobe of left lung
# 9   left upper lung zone
# 10  left lower lung zone
# 11  lingula
# 12  left mid lung zone
# 13  axillary region of left lung
# 14  upper lobe of right lung
# 15  upper lobe of right lung
# 16  apical segment of upper lobe of right lung
# 17  posterior segment of upper lobe of right lung
# 18  anterior segment of upper lobe of right lung
# 19  lower lobe of right lung
# 20  lower lobe of right lung
# 21  medial basal segment of lower lobe of right lung
# 22  middle lobe of lung
# 23  middle lobe of lung
# 24  middle lobe of lung
# 25  lateral segment of middle lobe of right lung
# 26  medial segment of middle lobe of right lung
# 27  superior segment of lower lobe of right lung
# 28  anterior basal segment of lower lobe of right lung
# 29  lateral basal segment of lower lobe of right lung
# 30  posterior basal segment of lower lobe of right lung
# 31  left upper lung zone
# 32  right upper lung zone
# 33  right mid lung zone
# 34  right lower lung zone
# 35  axillary region of right lung
#
#                                     synonym
# 0   LLL
# 1   left lower lobe
# 2   S6 segment of lower lobe of left lung
# 3   S7+8 segment of lower lobe of left lung
# 4   LUL
# 5   left upper lobe
# 6   S9 segment of lower lobe of left lung
# 7   S10 segment of lower lobe of left lung
# 8
# 9
# 10
# 11
# 12
# 13
# 14  RUL
# 15  right upper lobe
# 16  S1 segment of upper lobe of right lung
# 17  S2 segment of upper lobe of right lung
# 18  S3 segment of upper lobe of right lung
# 19  RLL
# 20  right lower lobe
# 21  S7 segment of lower lobe of right lung
# 22  RML
# 23  middle lobe of right lung
# 24  right middle lobe
# 25  S4 segment of middle lobe of right lung
# 26  S5 segment of middle lobe of right lung
# 27  S6 segment of lower lobe of right lung
# 28  S8 segment of lower lobe of right lung
# 29  S9 segment of lower lobe of right lung
# 30  S10 segment of lower lobe of right lung
# 31
# 32
# 33
# 34
# 35

# %%
term_frames = []
for key, df_key in df.groupby('seed_name'):
    Lst = list(set(df_key['name'].tolist() + df_key['synonym'].tolist()))
    Lst = [ x for x in Lst if x!='' ]
    
    terms = pd.DataFrame(Lst, columns=['meanings'])
    terms['keys'] = key
    term_frames.append(terms)

all_terms = pd.concat(term_frames, ignore_index=True)

# %%
all_terms
# Out:
#                                                  meanings        keys
# 0   lower lobe of left lung                                left lung
# 1   left lower lobe                                        left lung
# 2   S6 segment of lower lobe of left lung                  left lung
# 3   S7+8 segment of lower lobe of left lung                left lung
# 4   axillary region of left lung                           left lung
# 5   superior segment of lower lobe of left lung            left lung
# 6   anteromedial basal segment of lower lobe of left lung  left lung
# 7   left lower lung zone                                   left lung
# 8   left upper lung zone                                   left lung
# 9   lateral basal segment of lower lobe of left lung       left lung
# 10  S9 segment of lower lobe of left lung                  left lung
# 11  LLL                                                    left lung
# 12  S10 segment of lower lobe of left lung                 left lung
# 13  posterior basal segment of lower lobe of left lung     left lung
# 14  left mid lung zone                                     left lung
# 15  LUL                                                    left lung
# 16  superior division of upper lobe of left lung           left lung
# 17  left upper lobe                                        left lung
# 18  upper lobe of left lung                                left lung
# 19  lingula                                                left lung
# 20  medial segment of middle lobe of right lung            right lung
# 21  RML                                                    right lung
# 22  RLL                                                    right lung
# 23  S5 segment of middle lobe of right lung                right lung
# 24  S4 segment of middle lobe of right lung                right lung
# 25  lateral basal segment of lower lobe of right lung      right lung
# 26  right lower lobe                                       right lung
# 27  left upper lung zone                                   right lung
# 28  right mid lung zone                                    right lung
# 29  right upper lung zone                                  right lung
# 30  right lower lung zone                                  right lung
# 31  S7 segment of lower lobe of right lung                 right lung
# 32  medial basal segment of lower lobe of right lung       right lung
# 33  S9 segment of lower lobe of right lung                 right lung
# 34  posterior basal segment of lower lobe of right lung    right lung
# 35  anterior segment of upper lobe of right lung           right lung
# 36  right middle lobe                                      right lung
# 37  S10 segment of lower lobe of right lung                right lung
# 38  S2 segment of upper lobe of right lung                 right lung
# 39  axillary region of right lung                          right lung
# 40  lower lobe of right lung                               right lung
# 41  right upper lobe                                       right lung
# 42  RUL                                                    right lung
# 43  middle lobe of lung                                    right lung
# 44  middle lobe of right lung                              right lung
# 45  apical segment of upper lobe of right lung             right lung
# 46  S6 segment of lower lobe of right lung                 right lung
# 47  S3 segment of upper lobe of right lung                 right lung
# 48  S8 segment of lower lobe of right lung                 right lung
# 49  upper lobe of right lung                               right lung
# 50  S1 segment of upper lobe of right lung                 right lung
# 51  lateral segment of middle lobe of right lung           right lung
# 52  superior segment of lower lobe of right lung           right lung
# 53  anterior basal segment of lower lobe of right lung     right lung
# 54  posterior segment of upper lobe of right lung          right lung
