# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 500)

# %%
from SPARQLWrapper import SPARQLWrapper, CSV
from io import StringIO

# %%
sparql = SPARQLWrapper("http://localhost:8890/sparql")

# %%
qry = """
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX radlex: <http://www.radlex.org/RID/#>

SELECT DISTINCT ?RID ?name ?sub_name1 ?sub_name2 ?sub_name3 ?sub_name4 ?sub_name5 ?sub_name6 ?sub_name7 ?sub_name8 ?sub_name9 ?sub_name10 ?sub_name11 ?sub_name12
WHERE
{
 # ?term radlex:Preferred_name ?name .
 # ?term rdfs:label ?RID .
 FILTER regex(?RID,"RID12633",'i')
 OPTIONAL{?term radlex:Has_Subtype ?Sub_type1  .
 # ?Sub_type1 radlex:Preferred_name ?sub_name1 .
 OPTIONAL{?Sub_type1 radlex:Has_Subtype ?Sub_type2  .
 # ?Sub_type2 radlex:Preferred_name ?sub_name2 .
 OPTIONAL{?Sub_type2 radlex:Has_Subtype ?Sub_type3  .
 # ?Sub_type3 radlex:Preferred_name ?sub_name3 .
 OPTIONAL{?Sub_type3 radlex:Has_Subtype ?Sub_type4  .
 # ?Sub_type4 radlex:Preferred_name ?sub_name4 .
 OPTIONAL{?Sub_type4 radlex:Has_Subtype ?Sub_type5  .
 # ?Sub_type5 radlex:Preferred_name ?sub_name5 .
 OPTIONAL{?Sub_type5 radlex:Has_Subtype ?Sub_type6  .
 # ?Sub_type6 radlex:Preferred_name ?sub_name6 .
 OPTIONAL{?Sub_type6 radlex:Has_Subtype ?Sub_type7  .
 # ?Sub_type7 radlex:Preferred_name ?sub_name7 .

 
}}}}}}}}
"""

# %%
sparql.setQuery(qry)
sparql.setReturnFormat(CSV)
res = sparql.queryAndConvert()
resAsStr = res.decode('utf-8')

# %%
df = pd.read_csv(StringIO(resAsStr))
df.head(200)
# Out:
#          RID                             name                    sub_name1  \
# 0   RID12633  image processing procedure step  primary reconstruction step
# 1   RID12633  image processing procedure step  primary reconstruction step
# 2   RID12633  image processing procedure step  primary reconstruction step
# 3   RID12633  image processing procedure step  primary reconstruction step
# 4   RID12633  image processing procedure step  primary reconstruction step
# 5   RID12633  image processing procedure step  primary reconstruction step
# 6   RID12633  image processing procedure step  primary reconstruction step
# 7   RID12633  image processing procedure step  primary reconstruction step
# 8   RID12633  image processing procedure step  primary reconstruction step
# 9   RID12633  image processing procedure step  primary reconstruction step
# 10  RID12633  image processing procedure step  primary reconstruction step
# 11  RID12633  image processing procedure step  primary reconstruction step
# 12  RID12633  image processing procedure step  primary reconstruction step
# 13  RID12633  image processing procedure step  primary reconstruction step
# 14  RID12633  image processing procedure step  primary reconstruction step
# 15  RID12633  image processing procedure step  primary reconstruction step
# 16  RID12633  image processing procedure step  primary reconstruction step
# 17  RID12633  image processing procedure step  primary reconstruction step
# 18  RID12633  image processing procedure step  primary reconstruction step
# 19  RID12633  image processing procedure step  primary reconstruction step
# 20  RID12633  image processing procedure step  primary reconstruction step
# 21  RID12633  image processing procedure step  reformat procedure step
# 22  RID12633  image processing procedure step  reformat procedure step
# 23  RID12633  image processing procedure step  reformat procedure step
# 24  RID12633  image processing procedure step  primary reconstruction step
# 25  RID12633  image processing procedure step  primary reconstruction step
# 26  RID12633  image processing procedure step  primary reconstruction step
# 27  RID12633  image processing procedure step  primary reconstruction step
# 28  RID12633  image processing procedure step  primary reconstruction step
# 29  RID12633  image processing procedure step  primary reconstruction step
# 30  RID12633  image processing procedure step  primary reconstruction step
# 31  RID12633  image processing procedure step  primary reconstruction step
# 32  RID12633  image processing procedure step  primary reconstruction step
# 33  RID12633  image processing procedure step  primary reconstruction step
# 34  RID12633  image processing procedure step  primary reconstruction step
# 35  RID12633  image processing procedure step  reformat procedure step
# 36  RID12633  image processing procedure step  reformat procedure step
# 37  RID12633  image processing procedure step  reformat procedure step
# 38  RID12633  image processing procedure step  primary reconstruction step
# 39  RID12633  image processing procedure step  primary reconstruction step
# 40  RID12633  image processing procedure step  primary reconstruction step
# 41  RID12633  image processing procedure step  primary reconstruction step
# 42  RID12633  image processing procedure step  primary reconstruction step
# 43  RID12633  image processing procedure step  reformat procedure step
# 44  RID12633  image processing procedure step  reformat procedure step
# 45  RID12633  image processing procedure step  primary reconstruction step
# 46  RID12633  image processing procedure step  primary reconstruction step
# 47  RID12633  image processing procedure step  reformat procedure step
# 48  RID12633  image processing procedure step  reformat procedure step
# 49  RID12633  image processing procedure step  reformat procedure step
# 50  RID12633  image processing procedure step  reformat procedure step
# 51  RID12633  image processing procedure step  3D image processing
# 52  RID12633  image processing procedure step  computer-aided detection
#
#                                              sub_name2  \
# 0   MR primary reconstruction step
# 1   MR primary reconstruction step
# 2   MR primary reconstruction step
# 3   MR primary reconstruction step
# 4   MR primary reconstruction step
# 5   multiple acquisition reconstruction procedure step
# 6   MR primary reconstruction step
# 7   MR primary reconstruction step
# 8   MR primary reconstruction step
# 9   MR primary reconstruction step
# 10  MR primary reconstruction step
# 11  MR primary reconstruction step
# 12  MR primary reconstruction step
# 13  MR primary reconstruction step
# 14  MR primary reconstruction step
# 15  MR primary reconstruction step
# 16  MR primary reconstruction step
# 17  MR primary reconstruction step
# 18  MR primary reconstruction step
# 19  MR primary reconstruction step
# 20  MR primary reconstruction step
# 21  multiplanar reformat
# 22  filtering
# 23  filtering
# 24  MR primary reconstruction step
# 25  MR primary reconstruction step
# 26  multiple acquisition reconstruction procedure step
# 27  multiple acquisition reconstruction procedure step
# 28  MR primary reconstruction step
# 29  MR primary reconstruction step
# 30  MR primary reconstruction step
# 31  MR primary reconstruction step
# 32  MR primary reconstruction step
# 33  MR primary reconstruction step
# 34  multiple acquisition reconstruction procedure step
# 35  multiplanar reformat
# 36  multiplanar reformat
# 37  multiplanar reformat
# 38  MR primary reconstruction step
# 39  MR primary reconstruction step
# 40  MR primary reconstruction step
# 41  MR primary reconstruction step
# 42  MR primary reconstruction step
# 43  multiplanar reformat
# 44  multiplanar reformat
# 45  MR primary reconstruction step
# 46  CT primary reconstruction step
# 47  image segmentation
# 48  image registration
# 49  motion correction
# 50  region of interest editing
# 51  shaded surface display
# 52  NaN
#
#                                   sub_name3  \
# 0   diffusion-weighted image reconstruction
# 1   diffusion-weighted image reconstruction
# 2   diffusion-weighted image reconstruction
# 3   partial Fourier reconstruction
# 4   partial Fourier reconstruction
# 5   image fusion
# 6   interpolation
# 7   parallel imaging reconstruction
# 8   artifact correction technique
# 9   Fourier reconstruction
# 10  parallel imaging reconstruction
# 11  parallel imaging reconstruction
# 12  MR reconstruction filtering
# 13  MR reconstruction filtering
# 14  non-Cartesian reconstruction
# 15  diffusion-weighted image reconstruction
# 16  diffusion-weighted image reconstruction
# 17  MR reconstruction filtering
# 18  interpolation
# 19  interpolation
# 20  view-sharing
# 21  intensity projection
# 22  smoothing
# 23  smoothing
# 24  perfusion image reconstruction
# 25  view-sharing
# 26  computed imaging
# 27  computed imaging
# 28  non-Cartesian reconstruction
# 29  perfusion image reconstruction
# 30  view-sharing
# 31  phase reconstruction
# 32  phase reconstruction
# 33  view-sharing
# 34  image fusion
# 35  intensity projection
# 36  intensity projection
# 37  intensity projection
# 38  perfusion image reconstruction
# 39  perfusion image reconstruction
# 40  magnitude reconstruction
# 41  single-channel coil reconstruction
# 42  multiple coil reconstruction
# 43  volume rendering
# 44  curved planar reformation
# 45  real-time image reconstruction
# 46  NaN
# 47  NaN
# 48  NaN
# 49  NaN
# 50  NaN
# 51  NaN
# 52  NaN
#
#                                         sub_name4  \
# 0   trace of diffusion tensor reconstruction
# 1   trace of diffusion tensor reconstruction
# 2   trace of diffusion tensor reconstruction
# 3   iterative partial Fourier reconstruction
# 4   non-iterative partial Fourier reconstruction
# 5   hardware image fusion
# 6   between sections interpolation
# 7   image-based parallel imaging reconstruction
# 8   retrospective motion correction
# 9   discrete Fourier transform
# 10  k-space-based parallel imaging reconstruction
# 11  k-space-based parallel imaging reconstruction
# 12  image-based filtering
# 13  image-based filtering
# 14  filtered-backprojection
# 15  apparent diffusion coefficient map
# 16  diffusion tensor reconstruction
# 17  k-space filtering
# 18  zero-filling
# 19  in-plane filtering
# 20  BRISK
# 21  average intensity projection
# 22  temporal smoothing
# 23  spatial smoothing
# 24  time-to-peak map
# 25  sliding window reconstruction
# 26  parametric mapping
# 27  subtraction imaging
# 28  gridding
# 29  mean transit time map
# 30  TRICKS
# 31  phase difference reconstruction
# 32  phase unwrapping
# 33  keyhole
# 34  software image fusion
# 35  maximum intensity projection
# 36  minimum intensity projection
# 37  ray sum
# 38  cerebral blood volume map
# 39  cerebral blood flow map
# 40  NaN
# 41  NaN
# 42  NaN
# 43  NaN
# 44  NaN
# 45  NaN
# 46  NaN
# 47  NaN
# 48  NaN
# 49  NaN
# 50  NaN
# 51  NaN
# 52  NaN
#
#                                                                        sub_name5  \
# 0   fractional anisotropy map
# 1   relative anisotropy map
# 2   tractography
# 3   projection onto convex sets
# 4   homodyne
# 5   hardware image fusion with reregistration
# 6   zero-filling of 3D volume k-space data
# 7   SENSE reconstruction
# 8   periodically rotated overlapping parallel lines with enhanced reconstruction
# 9   fast Fourier transform
# 10  GRAPPA reconstruction
# 11  SMASH reconstruction
# 12  surface coil intensity correction
# 13  gradient nonlinearity correction
# 14  NaN
# 15  NaN
# 16  NaN
# 17  NaN
# 18  NaN
# 19  NaN
# 20  NaN
# 21  NaN
# 22  NaN
# 23  NaN
# 24  NaN
# 25  NaN
# 26  NaN
# 27  NaN
# 28  NaN
# 29  NaN
# 30  NaN
# 31  NaN
# 32  NaN
# 33  NaN
# 34  NaN
# 35  NaN
# 36  NaN
# 37  NaN
# 38  NaN
# 39  NaN
# 40  NaN
# 41  NaN
# 42  NaN
# 43  NaN
# 44  NaN
# 45  NaN
# 46  NaN
# 47  NaN
# 48  NaN
# 49  NaN
# 50  NaN
# 51  NaN
# 52  NaN
#
#     sub_name6  sub_name7  sub_name8  sub_name9  sub_name10  sub_name11  \
# 0  NaN        NaN        NaN        NaN        NaN         NaN
# 1  NaN        NaN        NaN        NaN        NaN         NaN
# 2  NaN        NaN        NaN        NaN        NaN         NaN
# 3  NaN        NaN        NaN        NaN        NaN         NaN
# 4  NaN        NaN        NaN        NaN        NaN         NaN
# 5  NaN        NaN        NaN        NaN        NaN         NaN
# 6  NaN        NaN        NaN        NaN        NaN         NaN
# 7  NaN        NaN        NaN        NaN        NaN         NaN
# 8  NaN        NaN        NaN        NaN        NaN         NaN
# 9  NaN        NaN        NaN        NaN        NaN         NaN
# 10 NaN        NaN        NaN        NaN        NaN         NaN
# 11 NaN        NaN        NaN        NaN        NaN         NaN
# 12 NaN        NaN        NaN        NaN        NaN         NaN
# 13 NaN        NaN        NaN        NaN        NaN         NaN
# 14 NaN        NaN        NaN        NaN        NaN         NaN
# 15 NaN        NaN        NaN        NaN        NaN         NaN
# 16 NaN        NaN        NaN        NaN        NaN         NaN
# 17 NaN        NaN        NaN        NaN        NaN         NaN
# 18 NaN        NaN        NaN        NaN        NaN         NaN
# 19 NaN        NaN        NaN        NaN        NaN         NaN
# 20 NaN        NaN        NaN        NaN        NaN         NaN
# 21 NaN        NaN        NaN        NaN        NaN         NaN
# 22 NaN        NaN        NaN        NaN        NaN         NaN
# 23 NaN        NaN        NaN        NaN        NaN         NaN
# 24 NaN        NaN        NaN        NaN        NaN         NaN
# 25 NaN        NaN        NaN        NaN        NaN         NaN
# 26 NaN        NaN        NaN        NaN        NaN         NaN
# 27 NaN        NaN        NaN        NaN        NaN         NaN
# 28 NaN        NaN        NaN        NaN        NaN         NaN
# 29 NaN        NaN        NaN        NaN        NaN         NaN
# 30 NaN        NaN        NaN        NaN        NaN         NaN
# 31 NaN        NaN        NaN        NaN        NaN         NaN
# 32 NaN        NaN        NaN        NaN        NaN         NaN
# 33 NaN        NaN        NaN        NaN        NaN         NaN
# 34 NaN        NaN        NaN        NaN        NaN         NaN
# 35 NaN        NaN        NaN        NaN        NaN         NaN
# 36 NaN        NaN        NaN        NaN        NaN         NaN
# 37 NaN        NaN        NaN        NaN        NaN         NaN
# 38 NaN        NaN        NaN        NaN        NaN         NaN
# 39 NaN        NaN        NaN        NaN        NaN         NaN
# 40 NaN        NaN        NaN        NaN        NaN         NaN
# 41 NaN        NaN        NaN        NaN        NaN         NaN
# 42 NaN        NaN        NaN        NaN        NaN         NaN
# 43 NaN        NaN        NaN        NaN        NaN         NaN
# 44 NaN        NaN        NaN        NaN        NaN         NaN
# 45 NaN        NaN        NaN        NaN        NaN         NaN
# 46 NaN        NaN        NaN        NaN        NaN         NaN
# 47 NaN        NaN        NaN        NaN        NaN         NaN
# 48 NaN        NaN        NaN        NaN        NaN         NaN
# 49 NaN        NaN        NaN        NaN        NaN         NaN
# 50 NaN        NaN        NaN        NaN        NaN         NaN
# 51 NaN        NaN        NaN        NaN        NaN         NaN
# 52 NaN        NaN        NaN        NaN        NaN         NaN
#
#     sub_name12
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
# 5  NaN
# 6  NaN
# 7  NaN
# 8  NaN
# 9  NaN
# 10 NaN
# 11 NaN
# 12 NaN
# 13 NaN
# 14 NaN
# 15 NaN
# 16 NaN
# 17 NaN
# 18 NaN
# 19 NaN
# 20 NaN
# 21 NaN
# 22 NaN
# 23 NaN
# 24 NaN
# 25 NaN
# 26 NaN
# 27 NaN
# 28 NaN
# 29 NaN
# 30 NaN
# 31 NaN
# 32 NaN
# 33 NaN
# 34 NaN
# 35 NaN
# 36 NaN
# 37 NaN
# 38 NaN
# 39 NaN
# 40 NaN
# 41 NaN
# 42 NaN
# 43 NaN
# 44 NaN
# 45 NaN
# 46 NaN
# 47 NaN
# 48 NaN
# 49 NaN
# 50 NaN
# 51 NaN
# 52 NaN

# %%
Lst = [df['name'].tolist(), df['sub_name1'].tolist(), df['sub_name2'].tolist(), df['sub_name3'].tolist(), df['sub_name4'].tolist(), df['sub_name5'].tolist()]

# %%
print(Lst)
# Out:
# [['image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step', 'image processing procedure step'], ['primary reconstruction step', 'primary reconstruction step', 'primary reconstruction step', 'primary reconstruction step', 'primary reconstruction step', 'primary reconstruction step', 'primary reconstruction step', 'primary reconstruction step', 'primary reconstruction step', 'primary reconstruction step', 'primary reconstruction step', 'primary reconstruction step', 'primary reconstruction step', 'primary reconstruction step', 'primary reconstruction step', 'primary reconstruction step', 'primary reconstruction step', 'primary reconstruction step', 'primary reconstruction step', 'primary reconstruction step', 'primary reconstruction step', 'reformat procedure step', 'reformat procedure step', 'reformat procedure step', 'primary reconstruction step', 'primary reconstruction step', 'primary reconstruction step', 'primary reconstruction step', 'primary reconstruction step', 'primary reconstruction step', 'primary reconstruction step', 'primary reconstruction step', 'primary reconstruction step', 'primary reconstruction step', 'primary reconstruction step', 'reformat procedure step', 'reformat procedure step', 'reformat procedure step', 'primary reconstruction step', 'primary reconstruction step', 'primary reconstruction step', 'primary reconstruction step', 'primary reconstruction step', 'reformat procedure step', 'reformat procedure step', 'primary reconstruction step', 'primary reconstruction step', 'reformat procedure step', 'reformat procedure step', 'reformat procedure step', 'reformat procedure step', '3D image processing', 'computer-aided detection'], ['MR primary reconstruction step', 'MR primary reconstruction step', 'MR primary reconstruction step', 'MR primary reconstruction step', 'MR primary reconstruction step', 'multiple acquisition reconstruction procedure step', 'MR primary reconstruction step', 'MR primary reconstruction step', 'MR primary reconstruction step', 'MR primary reconstruction step', 'MR primary reconstruction step', 'MR primary reconstruction step', 'MR primary reconstruction step', 'MR primary reconstruction step', 'MR primary reconstruction step', 'MR primary reconstructio ...

# %%
values = []
for lists in Lst:
    for string in lists:
        if str(string) == 'nan':
            pass
        else:
            values.append(string)

values = list(set(values))
dict_Radlex = {}
dict_Radlex['Process_related_words'] = values
print(dict_Radlex['Process_related_words'])
# Out:
# ['gradient nonlinearity correction', 'image fusion', 'interpolation', 'multiplanar reformat', 'MR primary reconstruction step', 'MR reconstruction filtering', 'image-based parallel imaging reconstruction', 'zero-filling of 3D volume k-space data', 'diffusion-weighted image reconstruction', 'retrospective motion correction', 'parallel imaging reconstruction', 'cerebral blood volume map', 'keyhole', 'discrete Fourier transform', 'hardware image fusion', 'homodyne', 'k-space filtering', 'ray sum', 'projection onto convex sets', 'multiple coil reconstruction', 'mean transit time map', 'trace of diffusion tensor reconstruction', 'tractography', 'filtering', 'shaded surface display', 'curved planar reformation', 'cerebral blood flow map', 'BRISK', 'image-based filtering', 'subtraction imaging', 'single-channel coil reconstruction', 'SMASH reconstruction', 'in-plane filtering', 'smoothing', 'minimum intensity projection', '3D image processing', 'SENSE reconstruction', 'artifact correction technique', 'non-Cartesian reconstruction', 'phase difference reconstruction', 'between sections interpolation', 'region of interest editing', 'reformat procedure step', 'apparent diffusion coefficient map', 'parametric mapping', 'intensity projection', 'software image fusion', 'gridding', 'temporal smoothing', 'relative anisotropy map', 'surface coil intensity correction', 'multiple acquisition reconstruction procedure step', 'CT primary reconstruction step', 'phase reconstruction', 'Fourier reconstruction', 'computed imaging', 'filtered-backprojection', 'zero-filling', 'sliding window reconstruction', 'fractional anisotropy map', 'GRAPPA reconstruction', 'computer-aided detection', 'motion correction', 'view-sharing', 'phase unwrapping', 'partial Fourier reconstruction', 'primary reconstruction step', 'diffusion tensor reconstruction', 'TRICKS', 'image processing procedure step', 'time-to-peak map', 'real-time image reconstruction', 'maximum intensity projection', 'non-iterative partial Fourier reconstruction', 'fast Fourier transform', 'k-space-based parallel imaging reconstruction', 'volume rendering', 'perfusion image reconstruction', 'average intensity projection', 'spatial smoothing', 'periodically rotated overlapping parallel lines with enhanced reconstruction', 'iterative partial Fourier reconstruction', 'magnitude reconstruction', 'hardware image fusion with reregistration', 'image segmentation', 'image registration']
