# %%
from rdflib import Graph, ConjunctiveGraph
import pandas as pd
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 500)

g = ConjunctiveGraph()

# %%
g.parse("Radlex&Clever/owlapi.xrdf")
# Out:
# <Graph identifier=file:///C:/Users/320026487/Downloads/NLP_Project/Radlex%26Clever/owlapi.xrdf (<class 'rdflib.graph.Graph'>)>

# %%
len(g)
# Out:
# 674842

# %%
for subj, pred, obj in g:
    if (subj, pred, obj) not in g:
        raise Exception("It better be!")

# %%
qry = """
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX radlex: <http://www.radlex.org/RID/#>

SELECT DISTINCT ?RID ?name ?sub_name1 ?sub_name2 ?sub_name3 ?sub_name4 ?sub_name5 ?sub_name6 ?sub_name7 ?sub_name8 ?sub_name9 ?sub_name10 ?sub_name11 ?sub_name12
WHERE
{
 # ?term radlex:Preferred_name ?name .
 # ?term rdfs:label ?RID .
 FILTER regex(?RID,"RID3874",'i')
 OPTIONAL{?term radlex:Has_Subtype ?Sub_type1  .
 # ?Sub_type1 radlex:Preferred_name ?sub_name1 .
 OPTIONAL{?Sub_type1 radlex:Has_Subtype ?Sub_type2  .
 # ?Sub_type2 radlex:Preferred_name ?sub_name2 .
 OPTIONAL{?Sub_type2 radlex:Has_Subtype ?Sub_type3  .
 # ?Sub_type3 radlex:Preferred_name ?sub_name3 .

 
}}}}
 """

rows  = g.query(qry)

# %%
len(rows.bindings)
# Out:
# 28

# %%
res = [{str(k): str(v) for k, v in binding.items()} for binding in rows.bindings]

# %%
df = pd.DataFrame(res)
    
df.head(200)
# Out:
#          RID                                                    name  \
# 0   RID38749  single phase
# 1   RID38745  iotrolan
# 2   RID38747  phase descriptor
# 3   RID38747  phase descriptor
# 4   RID38747  phase descriptor
# 5   RID38746  Isovist
# 6   RID38744  Visipaque-320
# 7   RID38741  iodixanol
# 8   RID38741  iodixanol
# 9   RID38748  multiphase
# 10  RID3874   mass
# 11  RID3874   mass
# 12  RID3874   mass
# 13  RID3874   mass
# 14  RID3874   mass
# 15  RID3874   mass
# 16  RID3874   mass
# 17  RID3874   mass
# 18  RID3874   mass
# 19  RID3874   mass
# 20  RID3874   mass
# 21  RID3874   mass
# 22  RID38743  Visipaque-270
# 23  RID38742  Visipaque
# 24  RID38742  Visipaque
# 25  RID38740  non-ionic iso-osmolar dimeric iodinated contrast agent
# 26  RID38740  non-ionic iso-osmolar dimeric iodinated contrast agent
# 27  RID38740  non-ionic iso-osmolar dimeric iodinated contrast agent
#
#                               sub_name1      sub_name2      sub_name3
# 0   NaN                                  NaN            NaN
# 1   Isovist                              NaN            NaN
# 2   triphase                             NaN            NaN
# 3   single phase                         NaN            NaN
# 4   multiphase                           NaN            NaN
# 5   NaN                                  NaN            NaN
# 6   NaN                                  NaN            NaN
# 7   Visipaque                            Visipaque-270  NaN
# 8   Visipaque                            Visipaque-320  NaN
# 9   NaN                                  NaN            NaN
# 10  lobular mass                         NaN            NaN
# 11  bone density                         NaN            NaN
# 12  liver mass                           NaN            NaN
# 13  chest mass                           lung mass      NaN
# 14  round mass                           NaN            NaN
# 15  benign prostatic hyperplasia nodule  NaN            NaN
# 16  breast mass                          NaN            NaN
# 17  irregular mass                       NaN            NaN
# 18  focal dominant mass                  NaN            NaN
# 19  oval mass                            NaN            NaN
# 20  mass in or on skin                   NaN            NaN
# 21  subthreshold lesion                  NaN            NaN
# 22  NaN                                  NaN            NaN
# 23  Visipaque-270                        NaN            NaN
# 24  Visipaque-320                        NaN            NaN
# 25  iotrolan                             Isovist        NaN
# 26  iodixanol                            Visipaque      Visipaque-270
# 27  iodixanol                            Visipaque      Visipaque-320

# %%
Lst = [df['name'].tolist(), df['sub_name1'].tolist(), df['sub_name2'].tolist(), df['sub_name3'].tolist()]

# %%
print(Lst)
# Out:
# [['single phase', 'iotrolan', 'phase descriptor', 'phase descriptor', 'phase descriptor', 'Isovist', 'Visipaque-320', 'iodixanol', 'iodixanol', 'multiphase', 'mass', 'mass', 'mass', 'mass', 'mass', 'mass', 'mass', 'mass', 'mass', 'mass', 'mass', 'mass', 'Visipaque-270', 'Visipaque', 'Visipaque', 'non-ionic iso-osmolar dimeric iodinated contrast agent', 'non-ionic iso-osmolar dimeric iodinated contrast agent', 'non-ionic iso-osmolar dimeric iodinated contrast agent'], [nan, 'Isovist', 'triphase', 'single phase', 'multiphase', nan, nan, 'Visipaque', 'Visipaque', nan, 'lobular mass', 'bone density', 'liver mass', 'chest mass', 'round mass', 'benign prostatic hyperplasia nodule', 'breast mass', 'irregular mass', 'focal dominant mass', 'oval mass', 'mass in or on skin', 'subthreshold lesion', nan, 'Visipaque-270', 'Visipaque-320', 'iotrolan', 'iodixanol', 'iodixanol'], [nan, nan, nan, nan, nan, nan, nan, 'Visipaque-270', 'Visipaque-320', nan, nan, nan, nan, 'lung mass', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 'Isovist', 'Visipaque', 'Visipaque'], [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 'Visipaque-270', 'Visipaque-320']]

# %%
values = []
for lists in Lst:
    for string in lists:
        if str(string) == 'nan':
            pass
        else:
            values.append(string)

values = list(set(values))
dict_Radlex = {}
dict_Radlex['Process_related_words'] = values
print(dict_Radlex['Process_related_words'])
# Out:
# ['triphase', 'Isovist', 'Visipaque', 'single phase', 'focal dominant mass', 'round mass', 'mass', 'irregular mass', 'Visipaque-270', 'bone density', 'phase descriptor', 'oval mass', 'iodixanol', 'multiphase', 'lung mass', 'subthreshold lesion', 'non-ionic iso-osmolar dimeric iodinated contrast agent', 'breast mass', 'Visipaque-320', 'liver mass', 'benign prostatic hyperplasia nodule', 'lobular mass', 'iotrolan', 'chest mass', 'mass in or on skin']
