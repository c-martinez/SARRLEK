# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 500)

# %%
from SPARQLWrapper import SPARQLWrapper, CSV
from io import StringIO

# %%
sparql = SPARQLWrapper("http://localhost:8890/sparql")

# %%
qry = """
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX radlex: <http://www.radlex.org/RID/#>

SELECT DISTINCT ?RID ?name ?sub_name1 ?sub_name2 ?sub_name3 ?synonym ?synonym1 ?synonym2 ?synonym3
WHERE
{
 # ?term radlex:Preferred_name ?name .
 FILTER regex(?name,"lung",'i')
 # ?term rdfs:label ?RID .
 OPTIONAL{?term radlex:Synonym ?synonym  .}
 
 OPTIONAL{?term radlex:Has_Subtype ?Sub_type1  .
 # ?Sub_type1 radlex:Preferred_name ?sub_name1 .
 # ?Sub_type1 rdfs:label ?sub1_RID .
 
 OPTIONAL{?Sub_type1 radlex:Synonym ?synonym1  .}
 
 OPTIONAL{?Sub_type1 radlex:Has_Subtype ?Sub_type2  .
 # ?Sub_type2 radlex:Preferred_name ?sub_name2 .
 # ?Sub_type2 rdfs:label ?sub2_RID .
 
 OPTIONAL{?Sub_type2 radlex:Synonym ?synonym2  .}
 
 OPTIONAL{?Sub_type2 radlex:Has_Subtype ?Sub_type3  .
 # ?Sub_type3 radlex:Preferred_name ?sub_name3 .
 # ?Sub_type3 rdfs:label ?sub3_RID .
 
 OPTIONAL{?Sub_type3 radlex:Synonym ?synonym3  .}
 

 }}}}
 """

# %%
sparql.setQuery(qry)
sparql.setReturnFormat(CSV)
res = sparql.queryAndConvert()
resAsStr = res.decode('utf-8')

# %%
df = pd.read_csv(StringIO(resAsStr))
df.head(200)
# Out:
#           RID                                                            name  \
# 0    RID10336  bremsstrahlung imaging
# 1    RID1347   lung zone
# 2    RID1347   lung zone
# 3    RID1347   lung zone
# 4    RID1347   lung zone
# 5    RID1347   lung zone
# 6    RID1347   lung zone
# 7    RID1347   lung zone
# 8    RID1347   lung zone
# 9    RID1347   lung zone
# 10   RID1347   lung zone
# 11   RID1347   lung zone
# 12   RID1301   lung
# 13   RID1348   upper lung zone
# 14   RID1348   upper lung zone
# 15   RID1301   lung
# 16   RID1290   anteromedial basal segment bronchus of lower lobe of left lung
# 17   RID1303   upper lobe of right lung
# 18   RID1303   upper lobe of right lung
# 19   RID1304   apical segment of upper lobe of right lung
# 20   RID1306   posterior segment of upper lobe of right lung
# 21   RID1308   anterior segment of upper lobe of right lung
# 22   RID1315   lower lobe of right lung
# 23   RID1315   lower lobe of right lung
# 24   RID1318   medial basal segment of lower lobe of right lung
# 25   RID1331   anterior segment of upper lobe of left lung
# 26   RID1338   lower lobe of left lung
# 27   RID1338   lower lobe of left lung
# 28   RID1339   superior segment of lower lobe of left lung
# 29   RID1341   anteromedial basal segment of lower lobe of left lung
# 30   RID1302   right lung
# 31   RID1328   superior division of upper lobe of left lung
# 32   RID13437  lungs
# 33   RID1349   left upper lung zone
# 34   RID1350   right upper lung zone
# 35   RID16726  neural network of lobe of lung
# 36   RID16726  neural network of lobe of lung
# 37   RID16726  neural network of lobe of lung
# 38   RID16726  neural network of lobe of lung
# 39   RID16726  neural network of lobe of lung
# 40   RID16730  neural network of middle lobe of lung
# 41   RID28799  interstitial lung disease
# 42   RID28584  apex of lung
# 43   RID28584  apex of lung
# 44   RID28584  apex of lung
# 45   RID34695  upper lobe of lung
# 46   RID34695  upper lobe of lung
# 47   RID34695  upper lobe of lung
# 48   RID34695  upper lobe of lung
# 49   RID35088  cluster-of-grapes sign of lung
# 50   RID35260  halo sign of lung
# 51   RID35280  honeycomb lung
# 52   RID35280  honeycomb lung
# 53   RID35615  target sign of lung
# 54   RID35688  wall sign of lung
# 55   RID35739  lung parenchyma
# 56   RID3866   Madelung disease
# 57   RID43250  anatomical line of lung
# 58   RID43250  anatomical line of lung
# 59   RID43258  horizontal fissure of right lung
# 60   RID50134  Lung-RADS assessment
# 61   RID50134  Lung-RADS assessment
# 62   RID50134  Lung-RADS assessment
# 63   RID50134  Lung-RADS assessment
# 64   RID50134  Lung-RADS assessment
# 65   RID50134  Lung-RADS assessment
# 66   RID50134  Lung-RADS assessment
# 67   RID50135  Lung-RADS 0
# 68   RID50136  Lung-RADS 1
# 69   RID50137  Lung-RADS 2
# 70   RID50138  Lung-RADS 3
# 71   RID50139  Lung-RADS 4A
# 72   RID50140  Lung-RADS 4B
# 73   RID50141  Lung-RADS 4X
# 74   RID1354   lower lung zone
# 75   RID1360   small lung component
# 76   RID1351   mid lung zone
# 77   RID1354   lower lung zone
# 78   RID1351   mid lung zone
# 79   RID1327   upper lobe of left lung
# 80   RID1327   upper lobe of left lung
# 81   RID1355   left lower lung zone
# 82   RID34939  region of surface of lobe of lung
# 83   RID34939  region of surface of lobe of lung
# 84   RID34939  region of surface of lobe of lung
# 85   RID34938  region of surface of lung
# 86   RID34938  region of surface of lung
# 87   RID34694  lobe of lung
# 88   RID34694  lobe of lung
# 89   RID34694  lobe of lung
# 90   RID34694  lobe of lung
# 91   RID34694  lobe of lung
# 92   RID34694  lobe of lung
# 93   RID34694  lobe of lung
# 94   RID34694  lobe of lung
# 95   RID34696  lower lobe of lung
# 96   RID34696  lower lobe of lung
# 97   RID34696  lower lobe of lung
# 98   RID34696  lower lobe of lung
# 99   RID34694  lobe of lung
# 100  RID34694  lobe of lung
# 101  RID34694  lobe of lung
# 102  RID28940  subsegmental lymph node of right lung
# 103  RID28941  subsegmental lymph node of left lung
# 104  RID45686  lung cancer
# 105  RID1310   middle lobe of lung
# 106  RID1310   middle lobe of lung
# 107  RID1310   middle lobe of lung
# 108  RID1311   lateral segment of middle lobe of right lung
# 109  RID1313   medial segment of middle lobe of right lung
# 110  RID1316   superior segment of lower lobe of right lung
# 111  RID1320   anterior basal segment of lower lobe of right lung
# 112  RID1322   lateral basal segment of lower lobe of right lung
# 113  RID1324   posterior basal segment of lower lobe of right lung
# 114  RID1329   apicoposterior segment of upper lobe of left lung
# 115  RID1343   lateral basal segment of lower lobe of left lung
# 116  RID1345   posterior basal segment of lower lobe of left lung
# 117  RID1326   left lung
# 118  RID1353   right mid lung zone
# 119  RID1356   right lower lung zone
# 120  RID1358   axillary region of right lung
# 121  RID35306  intercostal bulging lung sign
# 122  RID39056  lung mass
# 123  RID43251  subdivision of anterior margin of lung
# 124  RID43251  subdivision of anterior margin of lung
# 125  RID5328   chronic infiltrative lung disease
# 126  RID5328   chronic infiltrative lung disease
# 127  RID5328   chronic infiltrative lung disease
# 128  RID5328   chronic infiltrative lung disease
# 129  RID5328   chronic infiltrative lung disease
# 130  RID5328   chronic infiltrative lung disease
# 131  RID5328   chronic infiltrative lung disease
# 132  RID5328   chronic infiltrative lung disease
# 133  RID5328   chronic infiltrative lung disease
# 134  RID5328   chronic infiltrative lung disease
# 135  RID16731  neural network of lower lobe of lung
# 136  RID16731  neural network of lower lobe of lung
# 137  RID1352   left mid lung zone
# 138  RID1359   axillary region of left lung
# 139  RID16728  neural network of upper lobe of right lung
# 140  RID16732  neural network of lower lobe of right lung
# 141  RID16733  neural network of lower lobe of left lung
# 142  RID5339   respiratory broncholitis associated interstitial lung disease
# 143  RID5339   respiratory broncholitis associated interstitial lung disease
# 144  RID5339   respiratory broncholitis associated interstitial lung disease
# 145  RID5339   respiratory broncholitis associated interstitial lung disease
# 146  RID16727  neural network of upper lobe of lung
# 147  RID16727  neural network of upper lobe of lung
# 148  RID1440   cardiac notch of left lung
# 149  RID16729  neural network of upper lobe of left lung
# 150  RID16791  neural network of root of lung
# 151  RID28906  lung kernel
# 152  RID35299  incomplete border sign of lung
# 153  RID35359  Madelung deformity
#
#                                       sub_name1  \
# 0    NaN
# 1    upper lung zone
# 2    upper lung zone
# 3    lower lung zone
# 4    mid lung zone
# 5    lower lung zone
# 6    axillary region
# 7    mid lung zone
# 8    axillary region
# 9    apex of lung
# 10   apex of lung
# 11   apex of lung
# 12   right lung
# 13   left upper lung zone
# 14   right upper lung zone
# 15   left lung
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# 30   NaN
# 31   NaN
# 32   NaN
# 33   NaN
# 34   NaN
# 35   neural network of upper lobe of lung
# 36   neural network of lower lobe of lung
# 37   neural network of lower lobe of lung
# 38   neural network of upper lobe of lung
# 39   neural network of middle lobe of lung
# 40   NaN
# 41   pulmonary alveolar proteinosis
# 42   NaN
# 43   NaN
# 44   NaN
# 45   upper lobe of right lung
# 46   upper lobe of right lung
# 47   upper lobe of left lung
# 48   upper lobe of left lung
# 49   NaN
# 50   NaN
# 51   NaN
# 52   NaN
# 53   NaN
# 54   NaN
# 55   NaN
# 56   NaN
# 57   subdivision of anterior margin of lung
# 58   subdivision of anterior margin of lung
# 59   NaN
# 60   Lung-RADS 0
# 61   Lung-RADS 1
# 62   Lung-RADS 2
# 63   Lung-RADS 3
# 64   Lung-RADS 4A
# 65   Lung-RADS 4B
# 66   Lung-RADS 4X
# 67   NaN
# 68   NaN
# 69   NaN
# 70   NaN
# 71   NaN
# 72   NaN
# 73   NaN
# 74   left lower lung zone
# 75   secondary pulmonary lobule
# 76   right mid lung zone
# 77   right lower lung zone
# 78   left mid lung zone
# 79   NaN
# 80   NaN
# 81   NaN
# 82   pleural fissure
# 83   pleural fissure
# 84   pleural fissure
# 85   region of surface of lobe of lung
# 86   region of surface of lobe of lung
# 87   upper lobe of lung
# 88   upper lobe of lung
# 89   lower lobe of lung
# 90   lower lobe of lung
# 91   lower lobe of lung
# 92   lower lobe of lung
# 93   upper lobe of lung
# 94   upper lobe of lung
# 95   lower lobe of right lung
# 96   lower lobe of right lung
# 97   lower lobe of left lung
# 98   lower lobe of left lung
# 99   middle lobe of lung
# 100  middle lobe of lung
# 101  middle lobe of lung
# 102  NaN
# 103  NaN
# 104  NaN
# 105  NaN
# 106  NaN
# 107  NaN
# 108  NaN
# 109  NaN
# 110  NaN
# 111  NaN
# 112  NaN
# 113  NaN
# 114  NaN
# 115  NaN
# 116  NaN
# 117  NaN
# 118  NaN
# 119  NaN
# 120  NaN
# 121  NaN
# 122  NaN
# 123  anterior junction line
# 124  cardiac notch of left lung
# 125  interstitial pneumonia
# 126  interstitial pneumonia
# 127  interstitial pneumonia
# 128  interstitial pneumonia
# 129  interstitial pneumonia
# 130  interstitial pneumonia
# 131  interstitial pneumonia
# 132  interstitial pneumonia
# 133  interstitial pneumonia
# 134  interstitial pneumonia
# 135  neural network of lower lobe of right lung
# 136  neural network of lower lobe of left lung
# 137  NaN
# 138  NaN
# 139  NaN
# 140  NaN
# 141  NaN
# 142  NaN
# 143  NaN
# 144  NaN
# 145  NaN
# 146  neural network of upper lobe of right lung
# 147  neural network of upper lobe of left lung
# 148  NaN
# 149  NaN
# 150  NaN
# 151  NaN
# 152  NaN
# 153  NaN
#
#                                       sub_name2  \
# 0    NaN
# 1    left upper lung zone
# 2    right upper lung zone
# 3    left lower lung zone
# 4    right mid lung zone
# 5    right lower lung zone
# 6    axillary region of right lung
# 7    left mid lung zone
# 8    axillary region of left lung
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# 30   NaN
# 31   NaN
# 32   NaN
# 33   NaN
# 34   NaN
# 35   neural network of upper lobe of right lung
# 36   neural network of lower lobe of right lung
# 37   neural network of lower lobe of left lung
# 38   neural network of upper lobe of left lung
# 39   NaN
# 40   NaN
# 41   NaN
# 42   NaN
# 43   NaN
# 44   NaN
# 45   NaN
# 46   NaN
# 47   NaN
# 48   NaN
# 49   NaN
# 50   NaN
# 51   NaN
# 52   NaN
# 53   NaN
# 54   NaN
# 55   NaN
# 56   NaN
# 57   anterior junction line
# 58   cardiac notch of left lung
# 59   NaN
# 60   NaN
# 61   NaN
# 62   NaN
# 63   NaN
# 64   NaN
# 65   NaN
# 66   NaN
# 67   NaN
# 68   NaN
# 69   NaN
# 70   NaN
# 71   NaN
# 72   NaN
# 73   NaN
# 74   NaN
# 75   NaN
# 76   NaN
# 77   NaN
# 78   NaN
# 79   NaN
# 80   NaN
# 81   NaN
# 82   right pleural fissure
# 83   right pleural fissure
# 84   left pleural fissure
# 85   pleural fissure
# 86   pleural fissure
# 87   upper lobe of right lung
# 88   upper lobe of right lung
# 89   lower lobe of right lung
# 90   lower lobe of right lung
# 91   lower lobe of left lung
# 92   lower lobe of left lung
# 93   upper lobe of left lung
# 94   upper lobe of left lung
# 95   NaN
# 96   NaN
# 97   NaN
# 98   NaN
# 99   NaN
# 100  NaN
# 101  NaN
# 102  NaN
# 103  NaN
# 104  NaN
# 105  NaN
# 106  NaN
# 107  NaN
# 108  NaN
# 109  NaN
# 110  NaN
# 111  NaN
# 112  NaN
# 113  NaN
# 114  NaN
# 115  NaN
# 116  NaN
# 117  NaN
# 118  NaN
# 119  NaN
# 120  NaN
# 121  NaN
# 122  NaN
# 123  NaN
# 124  NaN
# 125  organizing pneumonia
# 126  organizing pneumonia
# 127  organizing pneumonia
# 128  chronic fibrosing interstitial pneumonia
# 129  lymphoid interstitial pneumonia
# 130  acute interstitial pneumonia
# 131  desquamative interstitial pneumonia
# 132  usual interstitial pneumonia
# 133  nonspecific interstitial pneumonia
# 134  lymphocytic interstitial pneumonia
# 135  NaN
# 136  NaN
# 137  NaN
# 138  NaN
# 139  NaN
# 140  NaN
# 141  NaN
# 142  NaN
# 143  NaN
# 144  NaN
# 145  NaN
# 146  NaN
# 147  NaN
# 148  NaN
# 149  NaN
# 150  NaN
# 151  NaN
# 152  NaN
# 153  NaN
#
#                             sub_name3  \
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# 30   NaN
# 31   NaN
# 32   NaN
# 33   NaN
# 34   NaN
# 35   NaN
# 36   NaN
# 37   NaN
# 38   NaN
# 39   NaN
# 40   NaN
# 41   NaN
# 42   NaN
# 43   NaN
# 44   NaN
# 45   NaN
# 46   NaN
# 47   NaN
# 48   NaN
# 49   NaN
# 50   NaN
# 51   NaN
# 52   NaN
# 53   NaN
# 54   NaN
# 55   NaN
# 56   NaN
# 57   NaN
# 58   NaN
# 59   NaN
# 60   NaN
# 61   NaN
# 62   NaN
# 63   NaN
# 64   NaN
# 65   NaN
# 66   NaN
# 67   NaN
# 68   NaN
# 69   NaN
# 70   NaN
# 71   NaN
# 72   NaN
# 73   NaN
# 74   NaN
# 75   NaN
# 76   NaN
# 77   NaN
# 78   NaN
# 79   NaN
# 80   NaN
# 81   NaN
# 82   right major fissure
# 83   right minor fissure
# 84   left major fissure
# 85   right pleural fissure
# 86   left pleural fissure
# 87   NaN
# 88   NaN
# 89   NaN
# 90   NaN
# 91   NaN
# 92   NaN
# 93   NaN
# 94   NaN
# 95   NaN
# 96   NaN
# 97   NaN
# 98   NaN
# 99   NaN
# 100  NaN
# 101  NaN
# 102  NaN
# 103  NaN
# 104  NaN
# 105  NaN
# 106  NaN
# 107  NaN
# 108  NaN
# 109  NaN
# 110  NaN
# 111  NaN
# 112  NaN
# 113  NaN
# 114  NaN
# 115  NaN
# 116  NaN
# 117  NaN
# 118  NaN
# 119  NaN
# 120  NaN
# 121  NaN
# 122  NaN
# 123  NaN
# 124  NaN
# 125  cryptogenic organizing pneumonia
# 126  cryptogenic organizing pneumonia
# 127  cryptogenic organizing pneumonia
# 128  idiopathic pulmonary fibrosis
# 129  NaN
# 130  NaN
# 131  NaN
# 132  NaN
# 133  NaN
# 134  NaN
# 135  NaN
# 136  NaN
# 137  NaN
# 138  NaN
# 139  NaN
# 140  NaN
# 141  NaN
# 142  NaN
# 143  NaN
# 144  NaN
# 145  NaN
# 146  NaN
# 147  NaN
# 148  NaN
# 149  NaN
# 150  NaN
# 151  NaN
# 152  NaN
# 153  NaN
#
#                                                            synonym  \
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   S7+8 bronchus of lower lobe of left lung
# 17   RUL
# 18   right upper lobe
# 19   S1 segment of upper lobe of right lung
# 20   S2 segment of upper lobe of right lung
# 21   S3 segment of upper lobe of right lung
# 22   RLL
# 23   right lower lobe
# 24   S7 segment of lower lobe of right lung
# 25   S3 segment of upper lobe of left lung
# 26   LLL
# 27   left lower lobe
# 28   S6 segment of lower lobe of left lung
# 29   S7+8 segment of lower lobe of left lung
# 30   NaN
# 31   NaN
# 32   NaN
# 33   NaN
# 34   NaN
# 35   NaN
# 36   NaN
# 37   NaN
# 38   NaN
# 39   NaN
# 40   NaN
# 41   interstitial disease
# 42   lung apex
# 43   pulm apex
# 44   pulmonary apex
# 45   NaN
# 46   NaN
# 47   NaN
# 48   NaN
# 49   cluster of grapes sign of lung
# 50   CT halo sign
# 51   end-stage lung disease
# 52   honeycombing
# 53   NaN
# 54   lung wall sign
# 55   NaN
# 56   benign symmetric lipomatosis
# 57   NaN
# 58   NaN
# 59   NaN
# 60   NaN
# 61   NaN
# 62   NaN
# 63   NaN
# 64   NaN
# 65   NaN
# 66   NaN
# 67   NaN
# 68   NaN
# 69   NaN
# 70   NaN
# 71   NaN
# 72   NaN
# 73   NaN
# 74   NaN
# 75   NaN
# 76   NaN
# 77   NaN
# 78   NaN
# 79   LUL
# 80   left upper lobe
# 81   NaN
# 82   NaN
# 83   NaN
# 84   NaN
# 85   NaN
# 86   NaN
# 87   NaN
# 88   NaN
# 89   NaN
# 90   NaN
# 91   NaN
# 92   NaN
# 93   NaN
# 94   NaN
# 95   NaN
# 96   NaN
# 97   NaN
# 98   NaN
# 99   NaN
# 100  NaN
# 101  NaN
# 102  14R thoracic lymph node
# 103  14L thoracic lymph node
# 104  NaN
# 105  RML
# 106  middle lobe of right lung
# 107  right middle lobe
# 108  S4 segment of middle lobe of right lung
# 109  S5 segment of middle lobe of right lung
# 110  S6 segment of lower lobe of right lung
# 111  S8 segment of lower lobe of right lung
# 112  S9 segment of lower lobe of right lung
# 113  S10 segment of lower lobe of right lung
# 114  S1+2 segment of upper lobe of left lung
# 115  S9 segment of lower lobe of left lung
# 116  S10 segment of lower lobe of left lung
# 117  NaN
# 118  NaN
# 119  NaN
# 120  NaN
# 121  NaN
# 122  mass
# 123  NaN
# 124  NaN
# 125  NaN
# 126  NaN
# 127  NaN
# 128  NaN
# 129  NaN
# 130  NaN
# 131  NaN
# 132  NaN
# 133  NaN
# 134  NaN
# 135  NaN
# 136  NaN
# 137  NaN
# 138  NaN
# 139  NaN
# 140  NaN
# 141  NaN
# 142  respiratory broncholitis-associated interstitial lung disease
# 143  RB-ILD
# 144  respiratory broncholitis
# 145  respiratory bronchiolitis-interstitial lung disease
# 146  NaN
# 147  NaN
# 148  cardiac incisura
# 149  NaN
# 150  NaN
# 151  NaN
# 152  NaN
# 153  NaN
#
#                       synonym1                   synonym2  \
# 0    NaN                        NaN
# 1    NaN                        NaN
# 2    NaN                        NaN
# 3    NaN                        NaN
# 4    NaN                        NaN
# 5    NaN                        NaN
# 6    NaN                        NaN
# 7    NaN                        NaN
# 8    NaN                        NaN
# 9    lung apex                  NaN
# 10   pulm apex                  NaN
# 11   pulmonary apex             NaN
# 12   NaN                        NaN
# 13   NaN                        NaN
# 14   NaN                        NaN
# 15   NaN                        NaN
# 16   NaN                        NaN
# 17   NaN                        NaN
# 18   NaN                        NaN
# 19   NaN                        NaN
# 20   NaN                        NaN
# 21   NaN                        NaN
# 22   NaN                        NaN
# 23   NaN                        NaN
# 24   NaN                        NaN
# 25   NaN                        NaN
# 26   NaN                        NaN
# 27   NaN                        NaN
# 28   NaN                        NaN
# 29   NaN                        NaN
# 30   NaN                        NaN
# 31   NaN                        NaN
# 32   NaN                        NaN
# 33   NaN                        NaN
# 34   NaN                        NaN
# 35   NaN                        NaN
# 36   NaN                        NaN
# 37   NaN                        NaN
# 38   NaN                        NaN
# 39   NaN                        NaN
# 40   NaN                        NaN
# 41   NaN                        NaN
# 42   NaN                        NaN
# 43   NaN                        NaN
# 44   NaN                        NaN
# 45   RUL                        NaN
# 46   right upper lobe           NaN
# 47   LUL                        NaN
# 48   left upper lobe            NaN
# 49   NaN                        NaN
# 50   NaN                        NaN
# 51   NaN                        NaN
# 52   NaN                        NaN
# 53   NaN                        NaN
# 54   NaN                        NaN
# 55   NaN                        NaN
# 56   NaN                        NaN
# 57   NaN                        anterior mediastinal line
# 58   NaN                        cardiac incisura
# 59   NaN                        NaN
# 60   NaN                        NaN
# 61   NaN                        NaN
# 62   NaN                        NaN
# 63   NaN                        NaN
# 64   NaN                        NaN
# 65   NaN                        NaN
# 66   NaN                        NaN
# 67   NaN                        NaN
# 68   NaN                        NaN
# 69   NaN                        NaN
# 70   NaN                        NaN
# 71   NaN                        NaN
# 72   NaN                        NaN
# 73   NaN                        NaN
# 74   NaN                        NaN
# 75   NaN                        NaN
# 76   NaN                        NaN
# 77   NaN                        NaN
# 78   NaN                        NaN
# 79   NaN                        NaN
# 80   NaN                        NaN
# 81   NaN                        NaN
# 82   pulmonary fissure          NaN
# 83   pulmonary fissure          NaN
# 84   pulmonary fissure          NaN
# 85   NaN                        pulmonary fissure
# 86   NaN                        pulmonary fissure
# 87   NaN                        RUL
# 88   NaN                        right upper lobe
# 89   NaN                        RLL
# 90   NaN                        right lower lobe
# 91   NaN                        LLL
# 92   NaN                        left lower lobe
# 93   NaN                        LUL
# 94   NaN                        left upper lobe
# 95   RLL                        NaN
# 96   right lower lobe           NaN
# 97   LLL                        NaN
# 98   left lower lobe            NaN
# 99   RML                        NaN
# 100  middle lobe of right lung  NaN
# 101  right middle lobe          NaN
# 102  NaN                        NaN
# 103  NaN                        NaN
# 104  NaN                        NaN
# 105  NaN                        NaN
# 106  NaN                        NaN
# 107  NaN                        NaN
# 108  NaN                        NaN
# 109  NaN                        NaN
# 110  NaN                        NaN
# 111  NaN                        NaN
# 112  NaN                        NaN
# 113  NaN                        NaN
# 114  NaN                        NaN
# 115  NaN                        NaN
# 116  NaN                        NaN
# 117  NaN                        NaN
# 118  NaN                        NaN
# 119  NaN                        NaN
# 120  NaN                        NaN
# 121  NaN                        NaN
# 122  NaN                        NaN
# 123  anterior mediastinal line  NaN
# 124  cardiac incisura           NaN
# 125  NaN                        NaN
# 126  NaN                        NaN
# 127  NaN                        NaN
# 128  NaN                        NaN
# 129  NaN                        NaN
# 130  NaN                        NaN
# 131  NaN                        NaN
# 132  NaN                        NaN
# 133  NaN                        NaN
# 134  NaN                        NaN
# 135  NaN                        NaN
# 136  NaN                        NaN
# 137  NaN                        NaN
# 138  NaN                        NaN
# 139  NaN                        NaN
# 140  NaN                        NaN
# 141  NaN                        NaN
# 142  NaN                        NaN
# 143  NaN                        NaN
# 144  NaN                        NaN
# 145  NaN                        NaN
# 146  NaN                        NaN
# 147  NaN                        NaN
# 148  NaN                        NaN
# 149  NaN                        NaN
# 150  NaN                        NaN
# 151  NaN                        NaN
# 152  NaN                        NaN
# 153  NaN                        NaN
#
#                                           synonym3
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# 30   NaN
# 31   NaN
# 32   NaN
# 33   NaN
# 34   NaN
# 35   NaN
# 36   NaN
# 37   NaN
# 38   NaN
# 39   NaN
# 40   NaN
# 41   NaN
# 42   NaN
# 43   NaN
# 44   NaN
# 45   NaN
# 46   NaN
# 47   NaN
# 48   NaN
# 49   NaN
# 50   NaN
# 51   NaN
# 52   NaN
# 53   NaN
# 54   NaN
# 55   NaN
# 56   NaN
# 57   NaN
# 58   NaN
# 59   NaN
# 60   NaN
# 61   NaN
# 62   NaN
# 63   NaN
# 64   NaN
# 65   NaN
# 66   NaN
# 67   NaN
# 68   NaN
# 69   NaN
# 70   NaN
# 71   NaN
# 72   NaN
# 73   NaN
# 74   NaN
# 75   NaN
# 76   NaN
# 77   NaN
# 78   NaN
# 79   NaN
# 80   NaN
# 81   NaN
# 82   right oblique interlobar fissure
# 83   right horizontal interlobar fissure
# 84   left oblique interlobar fissure
# 85   NaN
# 86   NaN
# 87   NaN
# 88   NaN
# 89   NaN
# 90   NaN
# 91   NaN
# 92   NaN
# 93   NaN
# 94   NaN
# 95   NaN
# 96   NaN
# 97   NaN
# 98   NaN
# 99   NaN
# 100  NaN
# 101  NaN
# 102  NaN
# 103  NaN
# 104  NaN
# 105  NaN
# 106  NaN
# 107  NaN
# 108  NaN
# 109  NaN
# 110  NaN
# 111  NaN
# 112  NaN
# 113  NaN
# 114  NaN
# 115  NaN
# 116  NaN
# 117  NaN
# 118  NaN
# 119  NaN
# 120  NaN
# 121  NaN
# 122  NaN
# 123  NaN
# 124  NaN
# 125  BOOP
# 126  COP
# 127  bronchiolitis obliterans organizing pneumonia
# 128  NaN
# 129  NaN
# 130  NaN
# 131  NaN
# 132  NaN
# 133  NaN
# 134  NaN
# 135  NaN
# 136  NaN
# 137  NaN
# 138  NaN
# 139  NaN
# 140  NaN
# 141  NaN
# 142  NaN
# 143  NaN
# 144  NaN
# 145  NaN
# 146  NaN
# 147  NaN
# 148  NaN
# 149  NaN
# 150  NaN
# 151  NaN
# 152  NaN
# 153  NaN

# %%
Lst = [df['name'].tolist(), df['sub_name1'].tolist(), df['sub_name2'].tolist(), df['sub_name3'].tolist(), df['synonym'].tolist(), df['synonym1'].tolist(), df['synonym2'].tolist(), df['synonym3'].tolist()]

# %%
print(Lst)
# Out:
# [['bremsstrahlung imaging', 'lung zone', 'lung zone', 'lung zone', 'lung zone', 'lung zone', 'lung zone', 'lung zone', 'lung zone', 'lung zone', 'lung zone', 'lung zone', 'lung', 'upper lung zone', 'upper lung zone', 'lung', 'anteromedial basal segment bronchus of lower lobe of left lung', 'upper lobe of right lung', 'upper lobe of right lung', 'apical segment of upper lobe of right lung', 'posterior segment of upper lobe of right lung', 'anterior segment of upper lobe of right lung', 'lower lobe of right lung', 'lower lobe of right lung', 'medial basal segment of lower lobe of right lung', 'anterior segment of upper lobe of left lung', 'lower lobe of left lung', 'lower lobe of left lung', 'superior segment of lower lobe of left lung', 'anteromedial basal segment of lower lobe of left lung', 'right lung', 'superior division of upper lobe of left lung', 'lungs', 'left upper lung zone', 'right upper lung zone', 'neural network of lobe of lung', 'neural network of lobe of lung', 'neural network of lobe of lung', 'neural network of lobe of lung', 'neural network of lobe of lung', 'neural network of middle lobe of lung', 'interstitial lung disease', 'apex of lung', 'apex of lung', 'apex of lung', 'upper lobe of lung', 'upper lobe of lung', 'upper lobe of lung', 'upper lobe of lung', 'cluster-of-grapes sign of lung', 'halo sign of lung', 'honeycomb lung', 'honeycomb lung', 'target sign of lung', 'wall sign of lung', 'lung parenchyma', 'Madelung disease', 'anatomical line of lung', 'anatomical line of lung', 'horizontal fissure of right lung', 'Lung-RADS assessment', 'Lung-RADS assessment', 'Lung-RADS assessment', 'Lung-RADS assessment', 'Lung-RADS assessment', 'Lung-RADS assessment', 'Lung-RADS assessment', 'Lung-RADS 0', 'Lung-RADS 1', 'Lung-RADS 2', 'Lung-RADS 3', 'Lung-RADS 4A', 'Lung-RADS 4B', 'Lung-RADS 4X', 'lower lung zone', 'small lung component', 'mid lung zone', 'lower lung zone', 'mid lung zone', 'upper lobe of left lung', 'upper lobe of left lung', 'left lower lung zone', 'region of surface of lobe of lung', 'region of surface of lobe of lung', 'region of surface of lobe of lung', 'region of surface of lung', 'region of surface of lung', 'lobe of lung', 'lobe of lung', 'lobe of lung', 'lobe of lung', 'lobe of lung', 'lobe of lung', 'lobe of lung', 'lobe of lung', 'lower lobe of lung', 'lower lobe of lung', 'lower lobe of lung', 'lower lobe of lung', 'lobe of lung', 'lobe of lung', 'lobe of lung', 'subsegmental lymph node of right lung', 'subsegmental lymph node of left lung', 'lung cancer', 'middle lobe of lung', 'middle lobe of lung', 'middle lobe of lung', 'lateral segment of middle lobe of right lung', 'medial segment of middle lobe of right lung', 'superior segment of lower lobe of right lung', 'anterior basal segment of lower lobe of right lung', 'lateral basal segment of lower lobe of right lung', 'posterior basal segment of lower lobe of right lung', 'apicoposterior segment of upper lobe of left lung', 'lateral basal segment of lower lobe of left lung', 'posterior basal segment of lower lobe of left lung', 'left lung', 'right mid lung zone', 'right lower lung zone', 'axillary region of right lung', 'intercostal bulging lung sign', 'lung mass', 'subdivision of anterior margin of lung', 'subdivision of anterior margin of lung', 'chronic infiltrative lung disease', 'chronic infiltrative lung disease', 'chronic infiltrative lung disease', 'chronic infiltrative lung disease', 'chronic infiltrative lung disease', 'chronic infiltrative lung disease', 'chronic infiltrative lung disease', 'chronic infiltrative lung disease', 'chronic infiltrative lung disease', 'chronic infiltrative lung disease', 'neural network of lower lobe of lung', 'neural network of lower lobe of lung', 'left mid lung zone', 'axillary region of left lung', 'neural network of upper lobe of right lung', 'neural network of lower lobe of right lung', 'neural network of lower lobe of left lung', 'respiratory broncholitis associated interstitial lung disea ...

# %%
Lung_values = []
for lists in Lst:
    for string in lists:
        if str(string) == 'nan':
            pass
        else:
            Lung_values.append(string)

Lung_values = list(set(Lung_values))
print(Lung_values)
# Out:
# ['lymphoid interstitial pneumonia', 'subsegmental lymph node of right lung', 'desquamative interstitial pneumonia', 'left upper lung zone', 'upper lung zone', 'RLL', 'nonspecific interstitial pneumonia', 'Lung-RADS 4B', 'right minor fissure', 'respiratory bronchiolitis-interstitial lung disease', 'lung cancer', 'right horizontal interlobar fissure', 'lower lung zone', 'cluster-of-grapes sign of lung', 'pulmonary apex', 'axillary region of left lung', 'left mid lung zone', 'chronic fibrosing interstitial pneumonia', 'superior segment of lower lobe of right lung', 'left lung', 'lung zone', 'pulmonary alveolar proteinosis', 'interstitial pneumonia', 'superior segment of lower lobe of left lung', 'S3 segment of upper lobe of right lung', 'Lung-RADS 4X', 'right lung', 'left upper lobe', 'right major fissure', 'neural network of upper lobe of left lung', 'region of surface of lung', 'anteromedial basal segment of lower lobe of left lung', 'neural network of lower lobe of left lung', '14R thoracic lymph node', 'upper lobe of lung', 'anterior junction line', 'Madelung disease', 'posterior segment of upper lobe of right lung', 'right upper lobe', 'lobe of lung', 'upper lobe of left lung', 'S5 segment of middle lobe of right lung', 'right lower lobe', 'neural network of lower lobe of right lung', 'Lung-RADS 4A', 'S10 segment of lower lobe of left lung', 'left major fissure', 'S8 segment of lower lobe of right lung', 'pulmonary fissure', 'intercostal bulging lung sign', 'honeycomb lung', 'mass', 'benign symmetric lipomatosis', 'target sign of lung', 'RML', 'neural network of middle lobe of lung', 'lateral basal segment of lower lobe of right lung', 'respiratory broncholitis', 'upper lobe of right lung', 'cardiac incisura', 'incomplete border sign of lung', 'right oblique interlobar fissure', '14L thoracic lymph node', 'Lung-RADS 1', 'right middle lobe', 'posterior basal segment of lower lobe of right lung', 'S6 segment of lower lobe of left lung', 'horizontal fissure of right lung', 'left lower lung zone', 'lung kernel', 'S6 segment of lower lobe of right lung', 'medial basal segment of lower lobe of right lung', 'RUL', 'neural network of lobe of lung', 'pleural fissure', 'lateral segment of middle lobe of right lung', 'honeycombing', 'medial segment of middle lobe of right lung', 'halo sign of lung', 'cardiac notch of left lung', 'lung parenchyma', 'neural network of upper lobe of lung', 'cryptogenic organizing pneumonia', 'lower lobe of left lung', 'BOOP', 'S7 segment of lower lobe of right lung', 'interstitial lung disease', 'region of surface of lobe of lung', 'usual interstitial pneumonia', 'S3 segment of upper lobe of left lung', 'anterior basal segment of lower lobe of right lung', 'Lung-RADS 0', 'lung', 'subsegmental lymph node of left lung', 'anteromedial basal segment bronchus of lower lobe of left lung', 'left pleural fissure', 'organizing pneumonia', 'anterior mediastinal line', 'bronchiolitis obliterans organizing pneumonia', 'lung apex', 'respiratory broncholitis-associated interstitial lung disease', 'lung wall sign', 'chronic infiltrative lung disease', 'lower lobe of lung', 'left lower lobe', 'CT halo sign', 'wall sign of lung', 'middle lobe of right lung', 'lungs', 'S9 segment of lower lobe of left lung', 'middle lobe of lung', 'LLL', 'lateral basal segment of lower lobe of left lung', 'pulm apex', 'interstitial disease', 'Lung-RADS 2', 'lower lobe of right lung', 'lung mass', 'S10 segment of lower lobe of right lung', 'left oblique interlobar fissure', 'cluster of grapes sign of lung', 'bremsstrahlung imaging', 'S1 segment of upper lobe of right lung', 'axillary region', 'axillary region of right lung', 'S7+8 bronchus of lower lobe of left lung', 'mid lung zone', 'LUL', 'COP', 'idiopathic pulmonary fibrosis', 'apex of lung', 'secondary pulmonary lobule', 'subdivision of anterior margin of lung', 'end-stage lung disease', 'S2 segment of upper lobe of right lung', 'anterior segment of upper lobe of left lung', 'S9 segmen ...
