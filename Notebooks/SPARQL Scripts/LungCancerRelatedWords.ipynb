# %%
from rdflib import Graph, ConjunctiveGraph
import pandas as pd
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 500)

g = ConjunctiveGraph()

# %%
g.parse("Radlex&Clever/owlapi.xrdf")
# Out:
# <Graph identifier=file:///C:/Users/320026487/Downloads/NLP_Project/Radlex%26Clever/owlapi.xrdf (<class 'rdflib.graph.Graph'>)>

# %%
len(g)
# Out:
# 674842

# %%
for subj, pred, obj in g:
    if (subj, pred, obj) not in g:
        raise Exception("It better be!")

# %%
qry = """
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX radlex: <http://www.radlex.org/RID/#>

SELECT DISTINCT ?RID ?name ?synonym ?sub_name1 ?sub1_RID ?sub_name2 ?sub2_RID ?sub_name3 ?sub3_RID ?synonym1 ?synonym2 ?synonym3 ?synonym4 ?synonym5 ?synonym6 ?Is_A_name1 ?Is_A_name2 ?Is_A_name3
WHERE
{
 # ?term radlex:Preferred_name ?name .
 FILTER regex(?name,"lung cancer",'i')
 # ?term rdfs:label ?RID .
 OPTIONAL{?term radlex:Synonym ?synonym  .}
 
 OPTIONAL{?term radlex:Is_A ?Sub_type1  .
 # ?Sub_type1 radlex:Preferred_name ?sub_name1 .
 # ?Sub_type1 rdfs:label ?sub1_RID .
 
 OPTIONAL{?Sub_type1 radlex:Synonym ?synonym1  .}
 
 OPTIONAL{?Sub_type1 radlex:Has_Subtype ?Sub_type2  .
 # ?Sub_type2 radlex:Preferred_name ?sub_name2 .
 # ?Sub_type2 rdfs:label ?sub2_RID .
 
 OPTIONAL{?Sub_type2 radlex:Synonym ?synonym2  .}
 
 OPTIONAL{?Sub_type2 radlex:Has_Subtype ?Sub_type3  .
 # ?Sub_type3 radlex:Preferred_name ?sub_name3 .
 # ?Sub_type3 rdfs:label ?sub3_RID .
 
 OPTIONAL{?Sub_type3 radlex:Synonym ?synonym3  .}
 

 }}}}
 """

rows  = g.query(qry)

# %%
len(rows.bindings)
# Out:
# 23

# %%
res = [{str(k): str(v) for k, v in binding.items()} for binding in rows.bindings]

# %%
df = pd.DataFrame(res)
    
df.head(200)
# Out:
#          RID         name  sub1_RID  sub2_RID  sub3_RID  \
# 0   RID45686  lung cancer  RID34616  RID45697  NaN
# 1   RID45686  lung cancer  RID34616  RID34669  RID34671
# 2   RID45686  lung cancer  RID34616  RID45688  NaN
# 3   RID45686  lung cancer  RID34616  RID45744  NaN
# 4   RID45686  lung cancer  RID34616  RID45696  NaN
# 5   RID45686  lung cancer  RID34616  RID45687  NaN
# 6   RID45686  lung cancer  RID34616  RID45683  NaN
# 7   RID45686  lung cancer  RID34616  RID45686  NaN
# 8   RID45686  lung cancer  RID34616  RID49953  NaN
# 9   RID45686  lung cancer  RID34616  RID45685  NaN
# 10  RID45686  lung cancer  RID34616  RID45690  NaN
# 11  RID45686  lung cancer  RID34616  RID45682  NaN
# 12  RID45686  lung cancer  RID34616  RID45684  NaN
# 13  RID45686  lung cancer  RID34616  RID45691  NaN
# 14  RID45686  lung cancer  RID34616  RID34617  NaN
# 15  RID45686  lung cancer  RID34616  RID3840   RID3842
# 16  RID45686  lung cancer  RID34616  RID3840   RID34835
# 17  RID45686  lung cancer  RID34616  RID3840   RID3843
# 18  RID45686  lung cancer  RID34616  RID3840   RID3844
# 19  RID45686  lung cancer  RID34616  RID45689  RID49502
# 20  RID45686  lung cancer  RID34616  RID45689  RID49502
# 21  RID45686  lung cancer  RID34616  RID45689  RID49502
# 22  RID45686  lung cancer  RID34616  RID34623  NaN
#
#                        sub_name1                     sub_name2  \
# 0   malignant neoplastic disease  head and neck cancer
# 1   malignant neoplastic disease  malignant neoplasm of pelvis
# 2   malignant neoplastic disease  pancreatic cancer
# 3   malignant neoplastic disease  cancer of unknown primary
# 4   malignant neoplastic disease  esophageal cancer
# 5   malignant neoplastic disease  ovarian cancer
# 6   malignant neoplastic disease  cervical cancer
# 7   malignant neoplastic disease  lung cancer
# 8   malignant neoplastic disease  metastatic disease
# 9   malignant neoplastic disease  endometrial cancer
# 10  malignant neoplastic disease  testicular cancer
# 11  malignant neoplastic disease  breast cancer
# 12  malignant neoplastic disease  colorectal cancer
# 13  malignant neoplastic disease  thyroid cancer
# 14  malignant neoplastic disease  melanoma
# 15  malignant neoplastic disease  lymphoma
# 16  malignant neoplastic disease  lymphoma
# 17  malignant neoplastic disease  lymphoma
# 18  malignant neoplastic disease  lymphoma
# 19  malignant neoplastic disease  prostate cancer
# 20  malignant neoplastic disease  prostate cancer
# 21  malignant neoplastic disease  prostate cancer
# 22  malignant neoplastic disease  gastric cancer
#
#                                      sub_name3 synonym1  \
# 0   NaN                                         cancer
# 1   malignant neoplasm of genitourinary system  cancer
# 2   NaN                                         cancer
# 3   NaN                                         cancer
# 4   NaN                                         cancer
# 5   NaN                                         cancer
# 6   NaN                                         cancer
# 7   NaN                                         cancer
# 8   NaN                                         cancer
# 9   NaN                                         cancer
# 10  NaN                                         cancer
# 11  NaN                                         cancer
# 12  NaN                                         cancer
# 13  NaN                                         cancer
# 14  NaN                                         cancer
# 15  Hodgkin lymphoma                            cancer
# 16  T-cell lymphoma                             cancer
# 17  non-Hodgkin lymphoma                        cancer
# 18  large cell lymphoma                         cancer
# 19  clinically significant prostate cancer      cancer
# 20  clinically significant prostate cancer      cancer
# 21  clinically significant prostate cancer      cancer
# 22  NaN                                         cancer
#
#                      synonym2                                synonym3
# 0   NaN                        NaN
# 1   malignant tumor of pelvis  NaN
# 2   NaN                        NaN
# 3   NaN                        NaN
# 4   NaN                        NaN
# 5   NaN                        NaN
# 6   NaN                        NaN
# 7   NaN                        NaN
# 8   metastasis                 NaN
# 9   NaN                        NaN
# 10  NaN                        NaN
# 11  NaN                        NaN
# 12  NaN                        NaN
# 13  NaN                        NaN
# 14  NaN                        NaN
# 15  lymphosarcoma              NaN
# 16  lymphosarcoma              malignant histiocytosis syndrome
# 17  lymphosarcoma              NaN
# 18  lymphosarcoma              NaN
# 19  carcinoma of prostate      intermediate high risk prostate cancer
# 20  cancer of prostate         intermediate high risk prostate cancer
# 21  prostate cancer, NOS       intermediate high risk prostate cancer
# 22  stomach cancer             NaN

# %%
Lst = [df['name'].tolist(), df['sub_name1'].tolist(), df['sub_name2'].tolist(), df['sub_name3'].tolist(), df['synonym1'].tolist(), df['synonym2'].tolist(), df['synonym3'].tolist()]

# %%
print(Lst)
# Out:
# [['lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer', 'lung cancer'], ['malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease', 'malignant neoplastic disease'], ['head and neck cancer', 'malignant neoplasm of pelvis', 'pancreatic cancer', 'cancer of unknown primary', 'esophageal cancer', 'ovarian cancer', 'cervical cancer', 'lung cancer', 'metastatic disease', 'endometrial cancer', 'testicular cancer', 'breast cancer', 'colorectal cancer', 'thyroid cancer', 'melanoma', 'lymphoma', 'lymphoma', 'lymphoma', 'lymphoma', 'prostate cancer', 'prostate cancer', 'prostate cancer', 'gastric cancer'], [nan, 'malignant neoplasm of genitourinary system', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 'Hodgkin lymphoma', 'T-cell lymphoma', 'non-Hodgkin lymphoma', 'large cell lymphoma', 'clinically significant prostate cancer', 'clinically significant prostate cancer', 'clinically significant prostate cancer', nan], ['cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer', 'cancer'], [nan, 'malignant tumor of pelvis', nan, nan, nan, nan, nan, nan, 'metastasis', nan, nan, nan, nan, nan, nan, 'lymphosarcoma', 'lymphosarcoma', 'lymphosarcoma', 'lymphosarcoma', 'carcinoma of prostate', 'cancer of prostate', 'prostate cancer, NOS', 'stomach cancer'], [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 'malignant histiocytosis syndrome', nan, nan, 'intermediate high risk prostate cancer', 'intermediate high risk prostate cancer', 'intermediate high risk prostate cancer', nan]]

# %%
Cancer_values = []
for lists in Lst:
    for string in lists:
        if str(string) == 'nan':
            pass
        else:
            Cancer_values.append(string)

Cancer_values = list(set(Cancer_values))
print(Cancer_values)
# Out:
# ['head and neck cancer', 'non-Hodgkin lymphoma', 'stomach cancer', 'malignant histiocytosis syndrome', 'metastatic disease', 'lymphosarcoma', 'ovarian cancer', 'lymphoma', 'cancer of prostate', 'intermediate high risk prostate cancer', 'lung cancer', 'breast cancer', 'large cell lymphoma', 'cancer', 'malignant neoplasm of pelvis', 'T-cell lymphoma', 'endometrial cancer', 'cervical cancer', 'colorectal cancer', 'esophageal cancer', 'prostate cancer', 'malignant tumor of pelvis', 'prostate cancer, NOS', 'testicular cancer', 'metastasis', 'gastric cancer', 'cancer of unknown primary', 'carcinoma of prostate', 'malignant neoplasm of genitourinary system', 'thyroid cancer', 'pancreatic cancer', 'clinically significant prostate cancer', 'malignant neoplastic disease', 'Hodgkin lymphoma', 'melanoma']
